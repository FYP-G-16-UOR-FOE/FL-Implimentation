# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import copy
from torch.utils.data import DataLoader, Subset
import gzip
import os
from scipy.stats import wasserstein_distance  # EMD calculation
from collections import defaultdict, Counter
import glob
from collections import Counter
from scipy.spatial.distance import jensenshannon

# %% [markdown]
# ### Data Partitioning

# %%
def load_data_from_disk(partition_id: int, only_server_test_data: bool = False):
    #save_dir = "../data/client_dataset"
    save_dir = "/content/drive/MyDrive/FYP/Implementations/dataset/client_data_set"
    BATCH_SIZE = 64

    if only_server_test_data:
        testset = torchvision.datasets.CIFAR10(
            root='./data', train=False, download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
            ])
        )
        return DataLoader(testset, batch_size=BATCH_SIZE)

    client_filenames = [
        os.path.join(save_dir, f'client_{partition_id}.pt.gz'),
        os.path.join(save_dir, f'iid_clients_{partition_id}.pt.gz')
    ]
    for path in client_filenames:
        if os.path.exists(path):
            partition_data_path = path
            break
    else:
        raise FileNotFoundError(f"No data file for client {partition_id}")

    with gzip.open(partition_data_path, 'rb') as f:
        device_data = torch.load(f, map_location='cpu')
    device_data = [(x.to(torch.float32), y) for x,y in device_data]
    np.random.shuffle(device_data)
    split = int(len(device_data)*0.8)
    train_data, test_data = device_data[:split], device_data[split:]

    normalize = transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    train_data = [(normalize(x), y) for x,y in train_data]
    test_data  = [(normalize(x), y) for x,y in test_data]

    trainloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
    valloader  = DataLoader(test_data,  batch_size=BATCH_SIZE)
    return trainloader, valloader

# %%
# Parameters
FL_ROUNDS = 50
LOCAL_EPOCHS = 6
NUM_CLIENTS = 50

# %%
client_dataset_list = []
for i in range(NUM_CLIENTS):
    trainloader, valloader = load_data_from_disk(i)
    client_dataset_list.append((trainloader, valloader))

# %%
import pickle

with open('/content/drive/MyDrive/FYP/Implementations/client_dataset_50.pkl', 'wb') as f:
    pickle.dump([], f)

# %% [markdown]
# ## Model

# %%
# Define the CNN model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 4 * 4, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 10)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # [B, 32, 16, 16]
        x = self.pool(F.relu(self.conv2(x)))  # [B, 64, 8, 8]
        x = self.pool(F.relu(self.conv3(x)))  # [B, 128, 4, 4]
        x = x.view(-1, 128 * 4 * 4)           # Flatten
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ## CLient

# %%
class Client:

    def __init__(self, id):
        self.id = id
        #self.trainloader, self.valloader = self.load_client_dataset_from_disk(id)
        self.trainloader, self.valloader = client_dataset_list[id]

    def load_client_dataset_from_disk(self, client_id: int):
        save_dir = "/content/drive/MyDrive/Engineering-UOR/Final Year Project/Implementations/data/client_data_set"
        BATCH_SIZE = 64

        client_filenames = [
            os.path.join(save_dir, f'client_{client_id}.pt.gz'),
            os.path.join(save_dir, f'iid_clients_{client_id}.pt.gz')
        ]
        for path in client_filenames:
            if os.path.exists(path):
                partition_data_path = path
                break
        else:
            raise FileNotFoundError(f"No data file for client {client_id}")

        with gzip.open(partition_data_path, 'rb') as f:
            device_data = torch.load(f, map_location='cpu')

        device_data = [(x.to(torch.float32), y) for x, y in device_data]
        np.random.shuffle(device_data)
        split = int(len(device_data) * 0.8)
        train_data, test_data = device_data[:split], device_data[split:]

        normalize = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        train_data = [(normalize(x), y) for x, y in train_data]
        test_data = [(normalize(x), y) for x, y in test_data]

        trainloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
        valloader = DataLoader(test_data, batch_size=BATCH_SIZE)
        return trainloader, valloader

    def calculate_label_distribution(self):
        all_labels = []
        for _, labels in self.trainloader:
            all_labels.extend(labels.tolist())
        for _, labels in self.valloader:
            all_labels.extend(labels.tolist())

        label_counts = Counter(all_labels)
        for i in range(10):
            label_counts.setdefault(i, 0)
        sorted_distribution = dict(sorted(label_counts.items()))
        return sorted_distribution

    def calculate_emd(self, client_dist, reference_dist):
        client_counts = np.array([client_dist[i] for i in range(10)], dtype=np.float32)
        reference_counts = np.array([reference_dist[i] for i in range(10)], dtype=np.float32)

        client_probs = client_counts / client_counts.sum() if client_counts.sum() > 0 else np.zeros_like(client_counts)
        reference_probs = reference_counts / reference_counts.sum()

        labels = np.arange(10)
        emd = wasserstein_distance(labels, labels, u_weights=client_probs, v_weights=reference_probs)
        return emd

    def calculate_js_divergence(self, client_dist, reference_dist):
        client_counts = np.array([client_dist[i] for i in range(10)], dtype=np.float32)
        reference_counts = np.array([reference_dist[i] for i in range(10)], dtype=np.float32)

        client_probs = client_counts / client_counts.sum() if client_counts.sum() > 0 else np.zeros_like(client_counts)
        reference_probs = reference_counts / reference_counts.sum()

        return jensenshannon(client_probs, reference_probs, base=2.0) ** 2

    def train_local(self, global_model, epochs, device):
        model = copy.deepcopy(global_model).to(device)
        model.train()
        optimizer = optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            total_loss = 0.0
            correct = 0
            total = 0

            for inputs, labels in self.trainloader:
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                total_loss += loss.item() * inputs.size(0)
                _, predicted = outputs.max(1)
                correct += predicted.eq(labels).sum().item()
                total += labels.size(0)

            avg_loss = total_loss / total
            accuracy = 100. * correct / total
            print(f"Client {self.id} Epoch {epoch + 1}: Loss = {avg_loss:.4f}, Accuracy = {accuracy:.2f}%")

        return model.state_dict()

# %% [markdown]
# ## Server

# %%
class Server:

    def __init__(self, model):
        self.model = model

    # FedAvg Algorithm
    def fed_avg(self, client_models_param_list):
        avg_params = copy.deepcopy(client_models_param_list[0])
        for key in avg_params:
            for i in range(1, len(client_models_param_list)):
                avg_params[key] += client_models_param_list[i][key]
            avg_params[key] /= len(client_models_param_list)
        return avg_params

    # Weighted FedAvg
    def weighted_fed_avg(self, models_params, weights):
        avg_params = copy.deepcopy(models_params[0])
        total_weight = sum(weights)
        for param_key in avg_params:
            weighted_sum = torch.zeros_like(avg_params[param_key])
            for i in range(len(models_params)):
                client_param = models_params[i][param_key]
                weighted_sum += client_param * weights[i]
            avg_params[param_key] = weighted_sum / total_weight
        return avg_params

    # Assign Weight For Clients based on IID nature mesures (EMD/JS/..)
    def emd_to_weights(self, client_emd_list):
        d_min, d_max = min(client_emd_list), max(client_emd_list)
        if d_max == d_min:
            return [1.0 for _ in client_emd_list]  # Avoid div by zero
        return [(1 - (emd - d_min) / (d_max - d_min)) for emd in client_emd_list]

    # Aggregation
    def aggregate_models(self, client_models, weights=None):
        if weights is None:
            aggregated_model_params = self.fed_avg(client_models)
        else:
            aggregated_model_params = self.weighted_fed_avg(client_models, weights)
        self.model.load_state_dict(aggregated_model_params)
        return self.model

    # Test Global Model
    def test_model(self, testloader, device):
        self.model.eval()
        correct, total = 0, 0
        total_loss = 0.0
        criterion = nn.CrossEntropyLoss()

        with torch.no_grad():
            for images, labels in testloader:
                images, labels = images.to(device), labels.to(device)
                outputs = self.model(images)  # FIXED: self.model
                loss = criterion(outputs, labels)
                total_loss += loss.item() * images.size(0)

                _, predicted = torch.max(outputs, 1)
                correct += (predicted == labels).sum().item()
                total += labels.size(0)

        avg_loss = total_loss / total
        accuracy = 100.0 * correct / total
        return accuracy, avg_loss

# %% [markdown]
# ## Federated Training Loop

# %%
global_testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))]))
global_testset_loader = DataLoader(global_testset, batch_size=64)

# %%
# Initialize global model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
global_model = Net().to(device)

server = Server(global_model)

global_accuracy_list = []
global_loss_list = []

for fl_round in range(FL_ROUNDS):
    print(f"\n--- Federated Learning Round {fl_round + 1} ---")

    clients_model_param_list = []
    client_dist_list = []
    client_emd_list = []
    client_js_list = []

    for i in range(NUM_CLIENTS):

        client = Client(i)  # Load client data

        print(f"\n Client {i}: Local Training")
        print("--------------------------------------------------")

        # Client Local Training
        local_model_params = client.train_local(
            global_model, epochs=LOCAL_EPOCHS, device=device
        )
        clients_model_param_list.append(local_model_params)


    # Aggregation
    server.aggregate_models(client_models=clients_model_param_list)

    # Evaluate Global Model
    accuracy, loss = server.test_model(testloader=global_testset_loader, device=device)
    global_accuracy_list.append(accuracy)
    global_loss_list.append(loss)

    print(f"\nFederated Learning Round {fl_round + 1}:")
    print(f"  Accuracy: {accuracy:.2f}%, Loss: {loss:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Client 0 Epoch 1: Loss = 0.2904, Accuracy = 90.84%
# Client 0 Epoch 2: Loss = 0.2695, Accuracy = 90.44%
# Client 0 Epoch 3: Loss = 0.1602, Accuracy = 94.68%
# Client 0 Epoch 4: Loss = 0.0498, Accuracy = 98.42%
# Client 0 Epoch 5: Loss = 0.0342, Accuracy = 99.01%
# Client 0 Epoch 6: Loss = 0.0143, Accuracy = 99.70%
#
#  Client 1: Local Training
# --------------------------------------------------
# Client 1 Epoch 1: Loss = 0.3731, Accuracy = 87.38%
# Client 1 Epoch 2: Loss = 0.1750, Accuracy = 93.49%
# Client 1 Epoch 3: Loss = 0.0866, Accuracy = 96.95%
# Client 1 Epoch 4: Loss = 0.0639, Accuracy = 97.43%
# Client 1 Epoch 5: Loss = 0.0239, Accuracy = 99.28%
# Client 1 Epoch 6: Loss = 0.0210, Accuracy = 99.28%
#
#  Client 2: Local Training
# --------------------------------------------------
# Client 2 Epoch 1: Loss = 0.2880, Accuracy = 90.92%
# Client 2 Epoch 2: Loss = 0.2306, Accuracy = 92.77%
# Client 2 Epoch 3: Loss = 0.0858, Accuracy = 97.19%
# Client 2 Epoch 4: Loss = 0.0474, Accuracy = 98.07%
# Client 2 Epoch 5: Loss = 0.0292, Accuracy = 98.95%
# Client 2 Epoch 6: Loss = 0.0131, Accuracy = 99.60%
#
#  Client 3: Local Training
# --------------------------------------------------
# Client 3 Epoch 1: Loss = 0.3084, Accuracy = 88.96%
# Client 3 Epoch 2: Loss = 0.1396, Accuracy = 94.44%
# Client 3 Epoch 3: Loss = 0.1343, Accuracy = 95.12%
# Client 3 Epoch 4: Loss = 0.0719, Accuracy = 97.60%
# Client 3 Epoch 5: Loss = 0.0536, Accuracy = 97.82%
# Client 3 Epoch 6: Loss = 0.0259, Accuracy = 99.17%
#
#  Client 4: Local Training
# --------------------------------------------------
# Client 4 Epoch 1: Loss = 0.1934, Accuracy = 94.65%
# Client 4 Epoch 2: Loss = 0.0985, Accuracy = 97.01%
# Client 4 Epoch 3: Loss = 0.0426, Accuracy = 98.35%
# Client 4 Epoch 4: Loss = 0.0141, Accuracy = 99.49%
# Client 4 Epoch 5: Loss = 0.0088, Accuracy = 99.68%
# Client 4 Epoch 6: Loss = 0.0080, Accuracy = 99.75%
#
#  Client 5: Local Training
# --------------------------------------------------
# Client 5 Epoch 1: Loss = 0.3717, Accuracy = 87.74%
# Client 5 Epoch 2: Loss = 0.1748, Accuracy = 93.14%
# Client 5 Epoch 3: Loss = 0.1283, Accuracy = 95.60%
# Client 5 Epoch 4: Loss = 0.0747, Accuracy = 98.07%
# Client 5 Epoch 5: Loss = 0.0339, Accuracy = 99.20%
# Client 5 Epoch 6: Loss = 0.0268, Accuracy = 99.20%
#
#  Client 6: Local Training
# --------------------------------------------------
# Client 6 Epoch 1: Loss = 0.2940, Accuracy = 89.43%
# Client 6 Epoch 2: Loss = 0.1081, Accuracy = 96.25%
# Client 6 Epoch 3: Loss = 0.0591, Accuracy = 98.04%
# Client 6 Epoch 4: Loss = 0.0416, Accuracy = 98.55%
# Client 6 Epoch 5: Loss = 0.0227, Accuracy = 99.44%
# Client 6 Epoch 6: Loss = 0.0207, Accuracy = 99.44%
#
#  Client 7: Local Training
# --------------------------------------------------
# Client 7 Epoch 1: Loss = 0.3444, Accuracy = 88.13%
# Client 7 Epoch 2: Loss = 0.1642, Accuracy = 94.44%
# Client 7 Epoch 3: Loss = 0.0887, Accuracy = 97.47%
# Client 7 Epoch 4: Loss = 0.0876, Accuracy = 96.91%
# Client 7 Epoch 5: Loss = 0.0536, Accuracy = 98.52%
# Client 7 Epoch 6: Loss = 0.0507, Accuracy = 98.33%
#
#  Client 8: Local Training
# --------------------------------------------------
# Client 8 Epoch 1: Loss = 0.3579, Accuracy = 87.24%
# Client 8 Epoch 2: Loss = 0.1713, Accuracy = 94.37%
# Client 8 Epoch 3: Loss = 0.0995, Accuracy = 96.70%
# Client 8 Epoch 4: Loss = 0.0761, Accuracy = 97.22%
# Client 8 Epoch 5: Loss = 0.0525, Accuracy = 98.06%
# Client 8 Epoch 6: Loss = 0.0364, Accuracy = 99.22%
#
#  Client 9: Local Training
# --------------------------------------------------
# Client 9 Epoch 1: Loss = 0.2646, Accuracy = 91.59%
# Client 9 Epoch 2: Loss = 0.1036, Accuracy = 96.78%
# Client 9 Epoch 3: Loss = 0.0644, Accuracy = 97.60%
# Client 9 Epoch 4: Loss = 0.0437, Accuracy = 98.80%
# Client 9 Epoch 5: Loss = 0.0231, Accuracy = 99.43%
# Client 9 Epoch 6: Loss = 0.0238, Accuracy = 99.18%
#
#  Client 10: Local Training
# --------------------------------------------------
# Client 10 Epoch 1: Loss = 0.2601, Accuracy = 91.17%
# Client 10 Epoch 2: Loss = 0.2331, Accuracy = 91.92%
# Client 10 Epoch 3: Loss = 0.2899, Accuracy = 89.09%
# Client 10 Epoch 4: Loss = 0.1024, Accuracy = 96.54%
# Client 10 Epoch 5: Loss = 0.0531, Accuracy = 98.21%
# Client 10 Epoch 6: Loss = 0.0499, Accuracy = 98.15%
#
#  Client 11: Local Training
# --------------------------------------------------
# Client 11 Epoch 1: Loss = 0.3781, Accuracy = 86.07%
# Client 11 Epoch 2: Loss = 0.2057, Accuracy = 93.18%
# Client 11 Epoch 3: Loss = 0.1139, Accuracy = 96.45%
# Client 11 Epoch 4: Loss = 0.0627, Accuracy = 98.31%
# Client 11 Epoch 5: Loss = 0.0433, Accuracy = 98.89%
# Client 11 Epoch 6: Loss = 0.0586, Accuracy = 98.25%
#
#  Client 12: Local Training
# --------------------------------------------------
# Client 12 Epoch 1: Loss = 0.2948, Accuracy = 89.90%
# Client 12 Epoch 2: Loss = 0.1560, Accuracy = 94.59%
# Client 12 Epoch 3: Loss = 0.0767, Accuracy = 98.01%
# Client 12 Epoch 4: Loss = 0.0447, Accuracy = 98.46%
# Client 12 Epoch 5: Loss = 0.0328, Accuracy = 98.97%
# Client 12 Epoch 6: Loss = 0.0455, Accuracy = 98.58%
#
#  Client 13: Local Training
# --------------------------------------------------
# Client 13 Epoch 1: Loss = 0.2388, Accuracy = 91.82%
# Client 13 Epoch 2: Loss = 0.1054, Accuracy = 96.93%
# Client 13 Epoch 3: Loss = 0.0565, Accuracy = 98.23%
# Client 13 Epoch 4: Loss = 0.0349, Accuracy = 99.22%
# Client 13 Epoch 5: Loss = 0.0193, Accuracy = 99.67%
# Client 13 Epoch 6: Loss = 0.0124, Accuracy = 99.80%
#
#  Client 14: Local Training
# --------------------------------------------------
# Client 14 Epoch 1: Loss = 0.3258, Accuracy = 89.00%
# Client 14 Epoch 2: Loss = 0.1794, Accuracy = 93.13%
# Client 14 Epoch 3: Loss = 0.0994, Accuracy = 96.49%
# Client 14 Epoch 4: Loss = 0.0393, Accuracy = 99.11%
# Client 14 Epoch 5: Loss = 0.0288, Accuracy = 99.04%
# Client 14 Epoch 6: Loss = 0.0291, Accuracy = 98.97%
#
#  Client 15: Local Training
# --------------------------------------------------
# Client 15 Epoch 1: Loss = 0.3440, Accuracy = 88.35%
# Client 15 Epoch 2: Loss = 0.1719, Accuracy = 93.92%
# Client 15 Epoch 3: Loss = 0.0936, Accuracy = 97.10%
# Client 15 Epoch 4: Loss = 0.0601, Accuracy = 98.18%
# Client 15 Epoch 5: Loss = 0.0446, Accuracy = 98.69%
# Client 15 Epoch 6: Loss = 0.0292, Accuracy = 99.26%
#
#  Client 16: Local Training
# --------------------------------------------------
# Client 16 Epoch 1: Loss = 0.2852, Accuracy = 90.91%
# Client 16 Epoch 2: Loss = 0.1234, Accuracy = 96.27%
# Client 16 Epoch 3: Loss = 0.0501, Accuracy = 98.98%
# Client 16 Epoch 4: Loss = 0.0313, Accuracy = 99.28%
# Client 16 Epoch 5: Loss = 0.0208, Accuracy = 99.58%
# Client 16 Epoch 6: Loss = 0.0154, Accuracy = 99.82%
#
#  Client 17: Local Training
# --------------------------------------------------
# Client 17 Epoch 1: Loss = 0.3623, Accuracy = 88.15%
# Client 17 Epoch 2: Loss = 0.1649, Accuracy = 93.99%
# Client 17 Epoch 3: Loss = 0.0868, Accuracy = 97.35%
# Client 17 Epoch 4: Loss = 0.0534, Accuracy = 98.35%
# Client 17 Epoch 5: Loss = 0.0343, Accuracy = 99.41%
# Client 17 Epoch 6: Loss = 0.0273, Accuracy = 99.35%
#
#  Client 18: Local Training
# --------------------------------------------------
# Client 18 Epoch 1: Loss = 0.3238, Accuracy = 88.53%
# Client 18 Epoch 2: Loss = 0.1246, Accuracy = 96.32%
# Client 18 Epoch 3: Loss = 0.0659, Accuracy = 97.95%
# Client 18 Epoch 4: Loss = 0.0470, Accuracy = 98.61%
# Client 18 Epoch 5: Loss = 0.0280, Accuracy = 99.15%
# Client 18 Epoch 6: Loss = 0.0280, Accuracy = 99.34%
#
#  Client 19: Local Training
# --------------------------------------------------
# Client 19 Epoch 1: Loss = 0.2842, Accuracy = 90.05%
# Client 19 Epoch 2: Loss = 0.1293, Accuracy = 95.21%
# Client 19 Epoch 3: Loss = 0.0748, Accuracy = 97.27%
# Client 19 Epoch 4: Loss = 0.0459, Accuracy = 98.67%
# Client 19 Epoch 5: Loss = 0.0317, Accuracy = 99.09%
# Client 19 Epoch 6: Loss = 0.0187, Accuracy = 99.70%
#
#  Client 20: Local Training
# --------------------------------------------------
# Client 20 Epoch 1: Loss = 0.2199, Accuracy = 92.37%
# Client 20 Epoch 2: Loss = 0.0949, Accuracy = 96.99%
# Client 20 Epoch 3: Loss = 0.0468, Accuracy = 98.60%
# Client 20 Epoch 4: Loss = 0.0248, Accuracy = 99.51%
# Client 20 Epoch 5: Loss = 0.0217, Accuracy = 99.51%
# Client 20 Epoch 6: Loss = 0.0149, Accuracy = 99.44%
#
#  Client 21: Local Training
# --------------------------------------------------
# Client 21 Epoch 1: Loss = 0.2034, Accuracy = 93.04%
# Client 21 Epoch 2: Loss = 0.1021, Accuracy = 97.04%
# Client 21 Epoch 3: Loss = 0.0517, Accuracy = 98.00%
# Client 21 Epoch 4: Loss = 0.0286, Accuracy = 99.16%
# Client 21 Epoch 5: Loss = 0.0262, Accuracy = 99.10%
# Client 21 Epoch 6: Loss = 0.0138, Accuracy = 99.61%
#
#  Client 22: Local Training
# --------------------------------------------------
# Client 22 Epoch 1: Loss = 0.2741, Accuracy = 89.91%
# Client 22 Epoch 2: Loss = 0.1264, Accuracy = 95.91%
# Client 22 Epoch 3: Loss = 0.0799, Accuracy = 97.18%
# Client 22 Epoch 4: Loss = 0.0538, Accuracy = 98.52%
# Client 22 Epoch 5: Loss = 0.0610, Accuracy = 98.17%
# Client 22 Epoch 6: Loss = 0.0396, Accuracy = 98.80%
#
#  Client 23: Local Training
# --------------------------------------------------
# Client 23 Epoch 1: Loss = 0.2663, Accuracy = 91.15%
# Client 23 Epoch 2: Loss = 0.1092, Accuracy = 96.28%
# Client 23 Epoch 3: Loss = 0.0675, Accuracy = 97.89%
# Client 23 Epoch 4: Loss = 0.0286, Accuracy = 99.23%
# Client 23 Epoch 5: Loss = 0.0251, Accuracy = 99.09%
# Client 23 Epoch 6: Loss = 0.0234, Accuracy = 99.30%
#
#  Client 24: Local Training
# --------------------------------------------------
# Client 24 Epoch 1: Loss = 0.4917, Accuracy = 81.88%
# Client 24 Epoch 2: Loss = 0.2796, Accuracy = 88.76%
# Client 24 Epoch 3: Loss = 0.1805, Accuracy = 93.42%
# Client 24 Epoch 4: Loss = 0.0961, Accuracy = 96.83%
# Client 24 Epoch 5: Loss = 0.0793, Accuracy = 97.01%
# Client 24 Epoch 6: Loss = 0.0490, Accuracy = 98.74%
#
#  Client 25: Local Training
# --------------------------------------------------
# Client 25 Epoch 1: Loss = 0.5078, Accuracy = 82.07%
# Client 25 Epoch 2: Loss = 0.3177, Accuracy = 89.35%
# Client 25 Epoch 3: Loss = 0.2010, Accuracy = 92.65%
# Client 25 Epoch 4: Loss = 0.1687, Accuracy = 93.85%
# Client 25 Epoch 5: Loss = 0.1897, Accuracy = 93.77%
# Client 25 Epoch 6: Loss = 0.1625, Accuracy = 94.52%
#
#  Client 26: Local Training
# --------------------------------------------------
# Client 26 Epoch 1: Loss = 0.5112, Accuracy = 83.05%
# Client 26 Epoch 2: Loss = 0.3486, Accuracy = 87.47%
# Client 26 Epoch 3: Loss = 0.2629, Accuracy = 90.17%
# Client 26 Epoch 4: Loss = 0.1715, Accuracy = 94.75%
# Client 26 Epoch 5: Loss = 0.1249, Accuracy = 95.57%
# Client 26 Epoch 6: Loss = 0.0910, Accuracy = 97.37%
#
#  Client 27: Local Training
# --------------------------------------------------
# Client 27 Epoch 1: Loss = 0.5052, Accuracy = 83.87%
# Client 27 Epoch 2: Loss = 0.3490, Accuracy = 87.85%
# Client 27 Epoch 3: Loss = 0.2472, Accuracy = 91.30%
# Client 27 Epoch 4: Loss = 0.2041, Accuracy = 93.17%
# Client 27 Epoch 5: Loss = 0.1336, Accuracy = 95.80%
# Client 27 Epoch 6: Loss = 0.0937, Accuracy = 97.30%
#
#  Client 28: Local Training
# --------------------------------------------------
# Client 28 Epoch 1: Loss = 0.5026, Accuracy = 82.30%
# Client 28 Epoch 2: Loss = 0.3005, Accuracy = 90.02%
# Client 28 Epoch 3: Loss = 0.2081, Accuracy = 92.42%
# Client 28 Epoch 4: Loss = 0.2061, Accuracy = 93.85%
# Client 28 Epoch 5: Loss = 0.1548, Accuracy = 94.67%
# Client 28 Epoch 6: Loss = 0.1009, Accuracy = 96.40%
#
#  Client 29: Local Training
# --------------------------------------------------
# Client 29 Epoch 1: Loss = 0.5200, Accuracy = 82.67%
# Client 29 Epoch 2: Loss = 0.3797, Accuracy = 85.75%
# Client 29 Epoch 3: Loss = 0.2524, Accuracy = 90.85%
# Client 29 Epoch 4: Loss = 0.1941, Accuracy = 93.55%
# Client 29 Epoch 5: Loss = 0.1371, Accuracy = 94.82%
# Client 29 Epoch 6: Loss = 0.1177, Accuracy = 95.95%
#
#  Client 30: Local Training
# --------------------------------------------------
# Client 30 Epoch 1: Loss = 0.5618, Accuracy = 78.84%
# Client 30 Epoch 2: Loss = 0.3967, Accuracy = 85.67%
# Client 30 Epoch 3: Loss = 0.3012, Accuracy = 90.02%
# Client 30 Epoch 4: Loss = 0.1628, Accuracy = 94.45%
# Client 30 Epoch 5: Loss = 0.1188, Accuracy = 95.87%
# Client 30 Epoch 6: Loss = 0.1085, Accuracy = 96.32%
#
#  Client 31: Local Training
# --------------------------------------------------
# Client 31 Epoch 1: Loss = 0.5325, Accuracy = 81.02%
# Client 31 Epoch 2: Loss = 0.4386, Accuracy = 84.85%
# Client 31 Epoch 3: Loss = 0.2970, Accuracy = 89.35%
# Client 31 Epoch 4: Loss = 0.1806, Accuracy = 94.00%
# Client 31 Epoch 5: Loss = 0.1083, Accuracy = 96.70%
# Client 31 Epoch 6: Loss = 0.0900, Accuracy = 97.75%
#
#  Client 32: Local Training
# --------------------------------------------------
# Client 32 Epoch 1: Loss = 0.5198, Accuracy = 82.97%
# Client 32 Epoch 2: Loss = 0.3145, Accuracy = 89.20%
# Client 32 Epoch 3: Loss = 0.2800, Accuracy = 89.57%
# Client 32 Epoch 4: Loss = 0.2156, Accuracy = 92.80%
# Client 32 Epoch 5: Loss = 0.1725, Accuracy = 93.70%
# Client 32 Epoch 6: Loss = 0.1606, Accuracy = 94.52%
#
#  Client 33: Local Training
# --------------------------------------------------
# Client 33 Epoch 1: Loss = 0.4788, Accuracy = 83.50%
# Client 33 Epoch 2: Loss = 0.3692, Accuracy = 88.07%
# Client 33 Epoch 3: Loss = 0.2506, Accuracy = 92.20%
# Client 33 Epoch 4: Loss = 0.1507, Accuracy = 95.12%
# Client 33 Epoch 5: Loss = 0.1138, Accuracy = 95.87%
# Client 33 Epoch 6: Loss = 0.0884, Accuracy = 97.22%
#
#  Client 34: Local Training
# --------------------------------------------------
# Client 34 Epoch 1: Loss = 0.5162, Accuracy = 82.07%
# Client 34 Epoch 2: Loss = 0.3823, Accuracy = 86.05%
# Client 34 Epoch 3: Loss = 0.2507, Accuracy = 91.52%
# Client 34 Epoch 4: Loss = 0.2007, Accuracy = 93.32%
# Client 34 Epoch 5: Loss = 0.1326, Accuracy = 96.02%
# Client 34 Epoch 6: Loss = 0.0724, Accuracy = 97.82%
#
#  Client 35: Local Training
# --------------------------------------------------
# Client 35 Epoch 1: Loss = 0.5432, Accuracy = 81.62%
# Client 35 Epoch 2: Loss = 0.3480, Accuracy = 87.40%
# Client 35 Epoch 3: Loss = 0.2270, Accuracy = 92.65%
# Client 35 Epoch 4: Loss = 0.2037, Accuracy = 92.87%
# Client 35 Epoch 5: Loss = 0.1721, Accuracy = 94.22%
# Client 35 Epoch 6: Loss = 0.1074, Accuracy = 96.77%
#
#  Client 36: Local Training
# --------------------------------------------------
# Client 36 Epoch 1: Loss = 0.4649, Accuracy = 83.95%
# Client 36 Epoch 2: Loss = 0.3112, Accuracy = 89.42%
# Client 36 Epoch 3: Loss = 0.2330, Accuracy = 92.12%
# Client 36 Epoch 4: Loss = 0.1689, Accuracy = 94.67%
# Client 36 Epoch 5: Loss = 0.1669, Accuracy = 94.15%
# Client 36 Epoch 6: Loss = 0.1242, Accuracy = 95.80%
#
#  Client 37: Local Training
# --------------------------------------------------
# Client 37 Epoch 1: Loss = 0.5442, Accuracy = 81.02%
# Client 37 Epoch 2: Loss = 0.3772, Accuracy = 86.95%
# Client 37 Epoch 3: Loss = 0.2242, Accuracy = 92.35%
# Client 37 Epoch 4: Loss = 0.1755, Accuracy = 94.00%
# Client 37 Epoch 5: Loss = 0.1232, Accuracy = 95.50%
# Client 37 Epoch 6: Loss = 0.1468, Accuracy = 94.82%
#
#  Client 38: Local Training
# --------------------------------------------------
# Client 38 Epoch 1: Loss = 0.4798, Accuracy = 84.10%
# Client 38 Epoch 2: Loss = 0.3868, Accuracy = 87.77%
# Client 38 Epoch 3: Loss = 0.2272, Accuracy = 92.35%
# Client 38 Epoch 4: Loss = 0.1638, Accuracy = 94.22%
# Client 38 Epoch 5: Loss = 0.1112, Accuracy = 96.62%
# Client 38 Epoch 6: Loss = 0.0886, Accuracy = 97.15%
#
#  Client 39: Local Training
# --------------------------------------------------
# Client 39 Epoch 1: Loss = 0.4623, Accuracy = 84.62%
# Client 39 Epoch 2: Loss = 0.3061, Accuracy = 90.47%
# Client 39 Epoch 3: Loss = 0.2767, Accuracy = 90.70%
# Client 39 Epoch 4: Loss = 0.1795, Accuracy = 93.77%
# Client 39 Epoch 5: Loss = 0.1397, Accuracy = 95.42%
# Client 39 Epoch 6: Loss = 0.1123, Accuracy = 96.47%
#
#  Client 40: Local Training
# --------------------------------------------------
# Client 40 Epoch 1: Loss = 0.5350, Accuracy = 82.07%
# Client 40 Epoch 2: Loss = 0.3261, Accuracy = 88.07%
# Client 40 Epoch 3: Loss = 0.2248, Accuracy = 92.57%
# Client 40 Epoch 4: Loss = 0.1835, Accuracy = 93.77%
# Client 40 Epoch 5: Loss = 0.1211, Accuracy = 96.17%
# Client 40 Epoch 6: Loss = 0.0812, Accuracy = 97.60%
#
#  Client 41: Local Training
# --------------------------------------------------
# Client 41 Epoch 1: Loss = 0.4556, Accuracy = 82.52%
# Client 41 Epoch 2: Loss = 0.3440, Accuracy = 87.85%
# Client 41 Epoch 3: Loss = 0.2188, Accuracy = 92.12%
# Client 41 Epoch 4: Loss = 0.1787, Accuracy = 94.30%
# Client 41 Epoch 5: Loss = 0.1306, Accuracy = 95.50%
# Client 41 Epoch 6: Loss = 0.1043, Accuracy = 96.32%
#
#  Client 42: Local Training
# --------------------------------------------------
# Client 42 Epoch 1: Loss = 0.5044, Accuracy = 82.22%
# Client 42 Epoch 2: Loss = 0.3923, Accuracy = 85.45%
# Client 42 Epoch 3: Loss = 0.2712, Accuracy = 91.00%
# Client 42 Epoch 4: Loss = 0.1746, Accuracy = 94.00%
# Client 42 Epoch 5: Loss = 0.1045, Accuracy = 96.62%
# Client 42 Epoch 6: Loss = 0.0813, Accuracy = 97.45%
#
#  Client 43: Local Training
# --------------------------------------------------
# Client 43 Epoch 1: Loss = 0.4546, Accuracy = 84.62%
# Client 43 Epoch 2: Loss = 0.2779, Accuracy = 90.47%
# Client 43 Epoch 3: Loss = 0.2139, Accuracy = 93.70%
# Client 43 Epoch 4: Loss = 0.1756, Accuracy = 93.25%
# Client 43 Epoch 5: Loss = 0.1914, Accuracy = 93.32%
# Client 43 Epoch 6: Loss = 0.2029, Accuracy = 92.95%
#
#  Client 44: Local Training
# --------------------------------------------------
# Client 44 Epoch 1: Loss = 0.5570, Accuracy = 81.17%
# Client 44 Epoch 2: Loss = 0.3656, Accuracy = 85.97%
# Client 44 Epoch 3: Loss = 0.2324, Accuracy = 92.12%
# Client 44 Epoch 4: Loss = 0.1687, Accuracy = 94.22%
# Client 44 Epoch 5: Loss = 0.1594, Accuracy = 94.90%
# Client 44 Epoch 6: Loss = 0.1143, Accuracy = 96.85%
#
#  Client 45: Local Training
# --------------------------------------------------
# Client 45 Epoch 1: Loss = 0.5192, Accuracy = 81.76%
# Client 45 Epoch 2: Loss = 0.3183, Accuracy = 88.14%
# Client 45 Epoch 3: Loss = 0.1899, Accuracy = 93.69%
# Client 45 Epoch 4: Loss = 0.1907, Accuracy = 93.54%
# Client 45 Epoch 5: Loss = 0.1335, Accuracy = 95.42%
# Client 45 Epoch 6: Loss = 0.1013, Accuracy = 96.10%
#
#  Client 46: Local Training
# --------------------------------------------------
# Client 46 Epoch 1: Loss = 0.5309, Accuracy = 81.38%
# Client 46 Epoch 2: Loss = 0.4154, Accuracy = 85.51%
# Client 46 Epoch 3: Loss = 0.2846, Accuracy = 90.09%
# Client 46 Epoch 4: Loss = 0.2044, Accuracy = 93.32%
# Client 46 Epoch 5: Loss = 0.1241, Accuracy = 96.17%
# Client 46 Epoch 6: Loss = 0.0844, Accuracy = 97.45%
#
#  Client 47: Local Training
# --------------------------------------------------
# Client 47 Epoch 1: Loss = 0.5469, Accuracy = 79.95%
# Client 47 Epoch 2: Loss = 0.3264, Accuracy = 88.36%
# Client 47 Epoch 3: Loss = 0.2399, Accuracy = 91.44%
# Client 47 Epoch 4: Loss = 0.2322, Accuracy = 90.84%
# Client 47 Epoch 5: Loss = 0.1688, Accuracy = 94.29%
# Client 47 Epoch 6: Loss = 0.1519, Accuracy = 95.20%
#
#  Client 48: Local Training
# --------------------------------------------------
# Client 48 Epoch 1: Loss = 0.4461, Accuracy = 83.93%
# Client 48 Epoch 2: Loss = 0.3508, Accuracy = 87.61%
# Client 48 Epoch 3: Loss = 0.2781, Accuracy = 90.02%
# Client 48 Epoch 4: Loss = 0.1642, Accuracy = 94.37%
# Client 48 Epoch 5: Loss = 0.1316, Accuracy = 95.57%
# Client 48 Epoch 6: Loss = 0.1330, Accuracy = 95.87%
#
#  Client 49: Local Training
# --------------------------------------------------
# Client 49 Epoch 1: Loss = 0.4733, Accuracy = 83.03%
# Client 49 Epoch 2: Loss = 0.3467, Accuracy = 87.69%
# Client 49 Epoch 3: Loss = 0.2447, Accuracy = 91.44%
# Client 49 Epoch 4: Loss = 0.1486, Accuracy = 94.89%
# Client 49 Epoch 5: Loss = 0.1234, Accuracy = 96.70%
# Client 49 Epoch 6: Loss = 0.0994, Accuracy = 96.70%
#
# Federated Learning Round 40:
#   Accuracy: 68.97%, Loss: 0.9537
#
# --- Federated Learning Round 41 ---
#
#  Client 0: Local Training
# --------------------------------------------------
# Client 0 Epoch 1: Loss = 0.2560, Accuracy = 93.00%
# Client 0 Epoch 2: Loss = 0.1200, Accuracy = 95.47%
# Client 0 Epoch 3: Loss = 0.0772, Accuracy = 97.24%
# Client 0 Epoch 4: Loss = 0.0591, Accuracy = 98.13%
# Client 0 Epoch 5: Loss = 0.0308, Accuracy = 99.31%
# Client 0 Epoch 6: Loss = 0.0164, Accuracy = 99.41%
#
#  Client 1: Local Training
# --------------------------------------------------
# Client 1 Epoch 1: Loss = 0.2899, Accuracy = 91.40%
# Client 1 Epoch 2: Loss = 0.1317, Accuracy = 94.45%
# Client 1 Epoch 3: Loss = 0.1588, Accuracy = 94.13%
# Client 1 Epoch 4: Loss = 0.0952, Accuracy = 96.54%
# Client 1 Epoch 5: Loss = 0.0648, Accuracy = 97.91%
# Client 1 Epoch 6: Loss = 0.0293, Accuracy = 98.79%
#
#  Client 2: Local Training
# --------------------------------------------------
# Client 2 Epoch 1: Loss = 0.3319, Accuracy = 90.19%
# Client 2 Epoch 2: Loss = 0.1898, Accuracy = 93.81%
# Client 2 Epoch 3: Loss = 0.0786, Accuracy = 97.03%
# Client 2 Epoch 4: Loss = 0.0404, Accuracy = 98.55%
# Client 2 Epoch 5: Loss = 0.0252, Accuracy = 99.20%
# Client 2 Epoch 6: Loss = 0.0188, Accuracy = 99.44%
#
#  Client 3: Local Training
# --------------------------------------------------
# Client 3 Epoch 1: Loss = 0.3264, Accuracy = 89.19%
# Client 3 Epoch 2: Loss = 0.1866, Accuracy = 92.34%
# Client 3 Epoch 3: Loss = 0.1011, Accuracy = 96.55%
# Client 3 Epoch 4: Loss = 0.0557, Accuracy = 97.82%
# Client 3 Epoch 5: Loss = 0.0335, Accuracy = 98.95%
# Client 3 Epoch 6: Loss = 0.0219, Accuracy = 99.25%
#
#  Client 4: Local Training
# --------------------------------------------------
# Client 4 Epoch 1: Loss = 0.2093, Accuracy = 94.46%
# Client 4 Epoch 2: Loss = 0.0922, Accuracy = 96.69%
# Client 4 Epoch 3: Loss = 0.0840, Accuracy = 97.45%
# Client 4 Epoch 4: Loss = 0.0858, Accuracy = 97.39%
# Client 4 Epoch 5: Loss = 0.0157, Accuracy = 99.49%
# Client 4 Epoch 6: Loss = 0.0040, Accuracy = 99.87%
#
#  Client 5: Local Training
# --------------------------------------------------
# Client 5 Epoch 1: Loss = 0.3535, Accuracy = 87.21%
# Client 5 Epoch 2: Loss = 0.1356, Accuracy = 95.54%
# Client 5 Epoch 3: Loss = 0.0824, Accuracy = 97.53%
# Client 5 Epoch 4: Loss = 0.0580, Accuracy = 97.93%
# Client 5 Epoch 5: Loss = 0.0554, Accuracy = 98.20%
# Client 5 Epoch 6: Loss = 0.0376, Accuracy = 98.93%
#
#  Client 6: Local Training
# --------------------------------------------------
# Client 6 Epoch 1: Loss = 0.2766, Accuracy = 91.16%
# Client 6 Epoch 2: Loss = 0.1354, Accuracy = 95.08%
# Client 6 Epoch 3: Loss = 0.0635, Accuracy = 97.93%
# Client 6 Epoch 4: Loss = 0.0346, Accuracy = 99.16%
# Client 6 Epoch 5: Loss = 0.0200, Accuracy = 99.44%
# Client 6 Epoch 6: Loss = 0.0156, Accuracy = 99.61%
#
#  Client 7: Local Training
# --------------------------------------------------
# Client 7 Epoch 1: Loss = 0.3489, Accuracy = 87.89%
# Client 7 Epoch 2: Loss = 0.1848, Accuracy = 92.83%
# Client 7 Epoch 3: Loss = 0.0871, Accuracy = 96.97%
# Client 7 Epoch 4: Loss = 0.0564, Accuracy = 98.15%
# Client 7 Epoch 5: Loss = 0.0320, Accuracy = 99.07%
# Client 7 Epoch 6: Loss = 0.0234, Accuracy = 99.38%
#
#  Client 8: Local Training
# --------------------------------------------------
# Client 8 Epoch 1: Loss = 0.3780, Accuracy = 87.44%
# Client 8 Epoch 2: Loss = 0.1886, Accuracy = 92.62%
# Client 8 Epoch 3: Loss = 0.1173, Accuracy = 95.47%
# Client 8 Epoch 4: Loss = 0.0632, Accuracy = 97.93%
# Client 8 Epoch 5: Loss = 0.0469, Accuracy = 98.45%
# Client 8 Epoch 6: Loss = 0.0609, Accuracy = 98.25%
#
#  Client 9: Local Training
# --------------------------------------------------
# Client 9 Epoch 1: Loss = 0.3050, Accuracy = 89.57%
# Client 9 Epoch 2: Loss = 0.1416, Accuracy = 95.01%
# Client 9 Epoch 3: Loss = 0.0694, Accuracy = 97.60%
# Client 9 Epoch 4: Loss = 0.0377, Accuracy = 98.80%
# Client 9 Epoch 5: Loss = 0.0253, Accuracy = 99.49%
# Client 9 Epoch 6: Loss = 0.0361, Accuracy = 98.86%
#
#  Client 10: Local Training
# --------------------------------------------------
# Client 10 Epoch 1: Loss = 0.2812, Accuracy = 90.76%
# Client 10 Epoch 2: Loss = 0.1532, Accuracy = 94.75%
# Client 10 Epoch 3: Loss = 0.0590, Accuracy = 98.44%
# Client 10 Epoch 4: Loss = 0.0322, Accuracy = 99.02%
# Client 10 Epoch 5: Loss = 0.2552, Accuracy = 91.80%
# Client 10 Epoch 6: Loss = 0.0778, Accuracy = 97.69%
#
#  Client 11: Local Training
# --------------------------------------------------
# Client 11 Epoch 1: Loss = 0.4230, Accuracy = 84.67%
# Client 11 Epoch 2: Loss = 0.2388, Accuracy = 91.43%
# Client 11 Epoch 3: Loss = 0.1269, Accuracy = 95.80%
# Client 11 Epoch 4: Loss = 0.0726, Accuracy = 98.02%
# Client 11 Epoch 5: Loss = 0.0499, Accuracy = 98.83%
# Client 11 Epoch 6: Loss = 0.0377, Accuracy = 98.95%
#
#  Client 12: Local Training
# --------------------------------------------------
# Client 12 Epoch 1: Loss = 0.3105, Accuracy = 88.74%
# Client 12 Epoch 2: Loss = 0.1175, Accuracy = 96.59%
# Client 12 Epoch 3: Loss = 0.0543, Accuracy = 98.26%
# Client 12 Epoch 4: Loss = 0.0466, Accuracy = 98.33%
# Client 12 Epoch 5: Loss = 0.0357, Accuracy = 99.10%
# Client 12 Epoch 6: Loss = 0.0228, Accuracy = 99.49%
#
#  Client 13: Local Training
# --------------------------------------------------
# Client 13 Epoch 1: Loss = 0.2284, Accuracy = 92.09%
# Client 13 Epoch 2: Loss = 0.0930, Accuracy = 97.71%
# Client 13 Epoch 3: Loss = 0.0506, Accuracy = 98.63%
# Client 13 Epoch 4: Loss = 0.0283, Accuracy = 99.22%
# Client 13 Epoch 5: Loss = 0.0209, Accuracy = 99.67%
# Client 13 Epoch 6: Loss = 0.0213, Accuracy = 99.48%
#
#  Client 14: Local Training
# --------------------------------------------------
# Client 14 Epoch 1: Loss = 0.2957, Accuracy = 89.83%
# Client 14 Epoch 2: Loss = 0.1062, Accuracy = 95.95%
# Client 14 Epoch 3: Loss = 0.0674, Accuracy = 97.53%
# Client 14 Epoch 4: Loss = 0.0509, Accuracy = 98.42%
# Client 14 Epoch 5: Loss = 0.0198, Accuracy = 99.66%
# Client 14 Epoch 6: Loss = 0.0138, Accuracy = 99.59%
#
#  Client 15: Local Training
# --------------------------------------------------
# Client 15 Epoch 1: Loss = 0.3354, Accuracy = 88.35%
# Client 15 Epoch 2: Loss = 0.1608, Accuracy = 94.49%
# Client 15 Epoch 3: Loss = 0.0776, Accuracy = 97.50%
# Client 15 Epoch 4: Loss = 0.0605, Accuracy = 97.95%
# Client 15 Epoch 5: Loss = 0.0573, Accuracy = 98.41%
# Client 15 Epoch 6: Loss = 0.0409, Accuracy = 98.86%
#
#  Client 16: Local Training
# --------------------------------------------------
# Client 16 Epoch 1: Loss = 0.2641, Accuracy = 91.58%
# Client 16 Epoch 2: Loss = 0.1029, Accuracy = 96.09%
# Client 16 Epoch 3: Loss = 0.0675, Accuracy = 98.01%
# Client 16 Epoch 4: Loss = 0.0498, Accuracy = 98.86%
# Client 16 Epoch 5: Loss = 0.0323, Accuracy = 99.16%
# Client 16 Epoch 6: Loss = 0.0296, Accuracy = 99.40%
#
#  Client 17: Local Training
# --------------------------------------------------
# Client 17 Epoch 1: Loss = 0.3303, Accuracy = 88.97%
# Client 17 Epoch 2: Loss = 0.1567, Accuracy = 94.81%
# Client 17 Epoch 3: Loss = 0.0826, Accuracy = 97.41%
# Client 17 Epoch 4: Loss = 0.0691, Accuracy = 97.35%
# Client 17 Epoch 5: Loss = 0.0376, Accuracy = 98.70%
# Client 17 Epoch 6: Loss = 0.0222, Accuracy = 99.47%
#
#  Client 18: Local Training
# --------------------------------------------------
# Client 18 Epoch 1: Loss = 0.2873, Accuracy = 89.67%
# Client 18 Epoch 2: Loss = 0.1157, Accuracy = 96.26%
# Client 18 Epoch 3: Loss = 0.0671, Accuracy = 97.89%
# Client 18 Epoch 4: Loss = 0.0363, Accuracy = 99.28%
# Client 18 Epoch 5: Loss = 0.0307, Accuracy = 99.03%
# Client 18 Epoch 6: Loss = 0.0276, Accuracy = 99.28%
#
#  Client 19: Local Training
# --------------------------------------------------
# Client 19 Epoch 1: Loss = 0.2992, Accuracy = 88.83%
# Client 19 Epoch 2: Loss = 0.1346, Accuracy = 95.15%
# Client 19 Epoch 3: Loss = 0.0736, Accuracy = 97.75%
# Client 19 Epoch 4: Loss = 0.0374, Accuracy = 99.21%
# Client 19 Epoch 5: Loss = 0.0334, Accuracy = 98.85%
# Client 19 Epoch 6: Loss = 0.0288, Accuracy = 99.21%
#
#  Client 20: Local Training
# --------------------------------------------------
# Client 20 Epoch 1: Loss = 0.2100, Accuracy = 92.02%
# Client 20 Epoch 2: Loss = 0.1050, Accuracy = 96.22%
# Client 20 Epoch 3: Loss = 0.0609, Accuracy = 98.18%
# Client 20 Epoch 4: Loss = 0.0316, Accuracy = 99.16%
# Client 20 Epoch 5: Loss = 0.0118, Accuracy = 99.86%
# Client 20 Epoch 6: Loss = 0.0126, Accuracy = 99.58%
#
#  Client 21: Local Training
# --------------------------------------------------
# Client 21 Epoch 1: Loss = 0.1929, Accuracy = 93.36%
# Client 21 Epoch 2: Loss = 0.0491, Accuracy = 98.13%
# Client 21 Epoch 3: Loss = 0.0361, Accuracy = 98.90%
# Client 21 Epoch 4: Loss = 0.0338, Accuracy = 98.97%
# Client 21 Epoch 5: Loss = 0.0288, Accuracy = 98.84%
# Client 21 Epoch 6: Loss = 0.0296, Accuracy = 99.23%
#
#  Client 22: Local Training
# --------------------------------------------------
# Client 22 Epoch 1: Loss = 0.3053, Accuracy = 89.98%
# Client 22 Epoch 2: Loss = 0.0998, Accuracy = 96.33%
# Client 22 Epoch 3: Loss = 0.0715, Accuracy = 97.39%
# Client 22 Epoch 4: Loss = 0.0414, Accuracy = 98.66%
# Client 22 Epoch 5: Loss = 0.0243, Accuracy = 99.29%
# Client 22 Epoch 6: Loss = 0.0146, Accuracy = 99.79%
#
#  Client 23: Local Training
# --------------------------------------------------
# Client 23 Epoch 1: Loss = 0.2651, Accuracy = 90.94%
# Client 23 Epoch 2: Loss = 0.1320, Accuracy = 95.44%
# Client 23 Epoch 3: Loss = 0.0757, Accuracy = 98.03%
# Client 23 Epoch 4: Loss = 0.0454, Accuracy = 98.67%
# Client 23 Epoch 5: Loss = 0.0326, Accuracy = 99.16%
# Client 23 Epoch 6: Loss = 0.0214, Accuracy = 99.37%
#
#  Client 24: Local Training
# --------------------------------------------------
# Client 24 Epoch 1: Loss = 0.5020, Accuracy = 80.86%
# Client 24 Epoch 2: Loss = 0.2915, Accuracy = 88.94%
# Client 24 Epoch 3: Loss = 0.1640, Accuracy = 94.20%
# Client 24 Epoch 4: Loss = 0.1129, Accuracy = 96.35%
# Client 24 Epoch 5: Loss = 0.0646, Accuracy = 97.73%
# Client 24 Epoch 6: Loss = 0.0614, Accuracy = 98.33%
#
#  Client 25: Local Training
# --------------------------------------------------
# Client 25 Epoch 1: Loss = 0.5440, Accuracy = 82.07%
# Client 25 Epoch 2: Loss = 0.3730, Accuracy = 87.92%
# Client 25 Epoch 3: Loss = 0.2502, Accuracy = 91.97%
# Client 25 Epoch 4: Loss = 0.1602, Accuracy = 95.35%
# Client 25 Epoch 5: Loss = 0.1399, Accuracy = 95.95%
# Client 25 Epoch 6: Loss = 0.1124, Accuracy = 96.25%
#
#  Client 26: Local Training
# --------------------------------------------------
# Client 26 Epoch 1: Loss = 0.5085, Accuracy = 82.07%
# Client 26 Epoch 2: Loss = 0.3323, Accuracy = 89.05%
# Client 26 Epoch 3: Loss = 0.2422, Accuracy = 91.52%
# Client 26 Epoch 4: Loss = 0.1856, Accuracy = 94.37%
# Client 26 Epoch 5: Loss = 0.1297, Accuracy = 95.95%
# Client 26 Epoch 6: Loss = 0.0983, Accuracy = 96.85%
#
#  Client 27: Local Training
# --------------------------------------------------
# Client 27 Epoch 1: Loss = 0.4664, Accuracy = 83.35%
# Client 27 Epoch 2: Loss = 0.3313, Accuracy = 89.50%
# Client 27 Epoch 3: Loss = 0.2334, Accuracy = 91.60%
# Client 27 Epoch 4: Loss = 0.1962, Accuracy = 93.25%
# Client 27 Epoch 5: Loss = 0.1190, Accuracy = 95.87%
# Client 27 Epoch 6: Loss = 0.0817, Accuracy = 97.60%
#
#  Client 28: Local Training
# --------------------------------------------------
# Client 28 Epoch 1: Loss = 0.4548, Accuracy = 83.57%
# Client 28 Epoch 2: Loss = 0.3655, Accuracy = 87.10%
# Client 28 Epoch 3: Loss = 0.2802, Accuracy = 90.55%
# Client 28 Epoch 4: Loss = 0.1814, Accuracy = 95.12%
# Client 28 Epoch 5: Loss = 0.1462, Accuracy = 94.97%
# Client 28 Epoch 6: Loss = 0.0843, Accuracy = 97.45%
#
#  Client 29: Local Training
# --------------------------------------------------
# Client 29 Epoch 1: Loss = 0.4916, Accuracy = 83.20%
# Client 29 Epoch 2: Loss = 0.4418, Accuracy = 85.52%
# Client 29 Epoch 3: Loss = 0.3244, Accuracy = 89.50%
# Client 29 Epoch 4: Loss = 0.1933, Accuracy = 93.62%
# Client 29 Epoch 5: Loss = 0.1373, Accuracy = 95.05%
# Client 29 Epoch 6: Loss = 0.1054, Accuracy = 96.55%
#
#  Client 30: Local Training
# --------------------------------------------------
# Client 30 Epoch 1: Loss = 0.5331, Accuracy = 81.10%
# Client 30 Epoch 2: Loss = 0.3983, Accuracy = 86.50%
# Client 30 Epoch 3: Loss = 0.2812, Accuracy = 90.25%
# Client 30 Epoch 4: Loss = 0.1909, Accuracy = 93.25%
# Client 30 Epoch 5: Loss = 0.1080, Accuracy = 96.77%
# Client 30 Epoch 6: Loss = 0.0887, Accuracy = 96.70%
#
#  Client 31: Local Training
# --------------------------------------------------
# Client 31 Epoch 1: Loss = 0.4772, Accuracy = 83.57%
# Client 31 Epoch 2: Loss = 0.3664, Accuracy = 88.75%
# Client 31 Epoch 3: Loss = 0.2801, Accuracy = 90.02%
# Client 31 Epoch 4: Loss = 0.2358, Accuracy = 92.87%
# Client 31 Epoch 5: Loss = 0.1699, Accuracy = 93.92%
# Client 31 Epoch 6: Loss = 0.1512, Accuracy = 94.82%
#
#  Client 32: Local Training
# --------------------------------------------------
# Client 32 Epoch 1: Loss = 0.4855, Accuracy = 81.92%
# Client 32 Epoch 2: Loss = 0.4133, Accuracy = 85.00%
# Client 32 Epoch 3: Loss = 0.2658, Accuracy = 90.40%
# Client 32 Epoch 4: Loss = 0.2018, Accuracy = 93.92%
# Client 32 Epoch 5: Loss = 0.1319, Accuracy = 94.90%
# Client 32 Epoch 6: Loss = 0.1507, Accuracy = 94.60%
#
#  Client 33: Local Training
# --------------------------------------------------
# Client 33 Epoch 1: Loss = 0.4759, Accuracy = 84.10%
# Client 33 Epoch 2: Loss = 0.3207, Accuracy = 89.50%
# Client 33 Epoch 3: Loss = 0.1904, Accuracy = 94.07%
# Client 33 Epoch 4: Loss = 0.1913, Accuracy = 93.25%
# Client 33 Epoch 5: Loss = 0.1465, Accuracy = 95.05%
# Client 33 Epoch 6: Loss = 0.0966, Accuracy = 97.00%
#
#  Client 34: Local Training
# --------------------------------------------------
# Client 34 Epoch 1: Loss = 0.5369, Accuracy = 81.47%
# Client 34 Epoch 2: Loss = 0.3349, Accuracy = 88.37%
# Client 34 Epoch 3: Loss = 0.2437, Accuracy = 91.90%
# Client 34 Epoch 4: Loss = 0.2107, Accuracy = 92.95%
# Client 34 Epoch 5: Loss = 0.1662, Accuracy = 93.92%
# Client 34 Epoch 6: Loss = 0.0936, Accuracy = 97.00%
#
#  Client 35: Local Training
# --------------------------------------------------
# Client 35 Epoch 1: Loss = 0.5383, Accuracy = 82.45%
# Client 35 Epoch 2: Loss = 0.3350, Accuracy = 88.67%
# Client 35 Epoch 3: Loss = 0.2439, Accuracy = 91.45%
# Client 35 Epoch 4: Loss = 0.1825, Accuracy = 94.60%
# Client 35 Epoch 5: Loss = 0.1203, Accuracy = 96.17%
# Client 35 Epoch 6: Loss = 0.1040, Accuracy = 96.85%
#
#  Client 36: Local Training
# --------------------------------------------------
# Client 36 Epoch 1: Loss = 0.4841, Accuracy = 83.27%
# Client 36 Epoch 2: Loss = 0.2963, Accuracy = 89.12%
# Client 36 Epoch 3: Loss = 0.2073, Accuracy = 92.42%
# Client 36 Epoch 4: Loss = 0.1684, Accuracy = 93.70%
# Client 36 Epoch 5: Loss = 0.1237, Accuracy = 95.95%
# Client 36 Epoch 6: Loss = 0.1101, Accuracy = 95.95%
#
#  Client 37: Local Training
# --------------------------------------------------
# Client 37 Epoch 1: Loss = 0.5710, Accuracy = 80.35%
# Client 37 Epoch 2: Loss = 0.4256, Accuracy = 84.62%
# Client 37 Epoch 3: Loss = 0.2930, Accuracy = 89.87%
# Client 37 Epoch 4: Loss = 0.1582, Accuracy = 94.60%
# Client 37 Epoch 5: Loss = 0.1063, Accuracy = 96.02%
# Client 37 Epoch 6: Loss = 0.1101, Accuracy = 96.70%
#
#  Client 38: Local Training
# --------------------------------------------------
# Client 38 Epoch 1: Loss = 0.5185, Accuracy = 81.17%
# Client 38 Epoch 2: Loss = 0.3572, Accuracy = 87.55%
# Client 38 Epoch 3: Loss = 0.3021, Accuracy = 90.10%
# Client 38 Epoch 4: Loss = 0.2303, Accuracy = 92.57%
# Client 38 Epoch 5: Loss = 0.1285, Accuracy = 96.17%
# Client 38 Epoch 6: Loss = 0.1300, Accuracy = 95.80%
#
#  Client 39: Local Training
# --------------------------------------------------
# Client 39 Epoch 1: Loss = 0.5276, Accuracy = 82.30%
# Client 39 Epoch 2: Loss = 0.4884, Accuracy = 82.90%
# Client 39 Epoch 3: Loss = 0.3041, Accuracy = 89.72%
# Client 39 Epoch 4: Loss = 0.1558, Accuracy = 94.90%
# Client 39 Epoch 5: Loss = 0.1155, Accuracy = 96.55%
# Client 39 Epoch 6: Loss = 0.0887, Accuracy = 97.00%
#
#  Client 40: Local Training
# --------------------------------------------------
# Client 40 Epoch 1: Loss = 0.4587, Accuracy = 84.02%
# Client 40 Epoch 2: Loss = 0.3196, Accuracy = 89.05%
# Client 40 Epoch 3: Loss = 0.2173, Accuracy = 92.95%
# Client 40 Epoch 4: Loss = 0.1866, Accuracy = 94.37%
# Client 40 Epoch 5: Loss = 0.1684, Accuracy = 94.90%
# Client 40 Epoch 6: Loss = 0.1172, Accuracy = 96.47%
#
#  Client 41: Local Training
# --------------------------------------------------
# Client 41 Epoch 1: Loss = 0.5101, Accuracy = 82.67%
# Client 41 Epoch 2: Loss = 0.4053, Accuracy = 85.60%
# Client 41 Epoch 3: Loss = 0.2566, Accuracy = 91.22%
# Client 41 Epoch 4: Loss = 0.1781, Accuracy = 93.17%
# Client 41 Epoch 5: Loss = 0.1144, Accuracy = 96.77%
# Client 41 Epoch 6: Loss = 0.0827, Accuracy = 97.75%
#
#  Client 42: Local Training
# --------------------------------------------------
# Client 42 Epoch 1: Loss = 0.4860, Accuracy = 82.52%
# Client 42 Epoch 2: Loss = 0.4099, Accuracy = 85.45%
# Client 42 Epoch 3: Loss = 0.2751, Accuracy = 91.15%
# Client 42 Epoch 4: Loss = 0.1657, Accuracy = 94.82%
# Client 42 Epoch 5: Loss = 0.1467, Accuracy = 94.97%
# Client 42 Epoch 6: Loss = 0.1270, Accuracy = 95.87%
#
#  Client 43: Local Training
# --------------------------------------------------
# Client 43 Epoch 1: Loss = 0.5958, Accuracy = 79.67%
# Client 43 Epoch 2: Loss = 0.4571, Accuracy = 83.87%
# Client 43 Epoch 3: Loss = 0.2827, Accuracy = 90.92%
# Client 43 Epoch 4: Loss = 0.1639, Accuracy = 94.15%
# Client 43 Epoch 5: Loss = 0.1257, Accuracy = 96.32%
# Client 43 Epoch 6: Loss = 0.0907, Accuracy = 96.62%
#
#  Client 44: Local Training
# --------------------------------------------------
# Client 44 Epoch 1: Loss = 0.5242, Accuracy = 82.30%
# Client 44 Epoch 2: Loss = 0.3225, Accuracy = 88.75%
# Client 44 Epoch 3: Loss = 0.2310, Accuracy = 91.30%
# Client 44 Epoch 4: Loss = 0.1667, Accuracy = 94.67%
# Client 44 Epoch 5: Loss = 0.1246, Accuracy = 95.57%
# Client 44 Epoch 6: Loss = 0.1318, Accuracy = 95.65%
#
#  Client 45: Local Training
# --------------------------------------------------
# Client 45 Epoch 1: Loss = 0.4861, Accuracy = 83.03%
# Client 45 Epoch 2: Loss = 0.3613, Accuracy = 86.64%
# Client 45 Epoch 3: Loss = 0.2674, Accuracy = 90.69%
# Client 45 Epoch 4: Loss = 0.1910, Accuracy = 93.62%
# Client 45 Epoch 5: Loss = 0.1532, Accuracy = 95.12%
# Client 45 Epoch 6: Loss = 0.0934, Accuracy = 96.62%
#
#  Client 46: Local Training
# --------------------------------------------------
# Client 46 Epoch 1: Loss = 0.5181, Accuracy = 82.21%
# Client 46 Epoch 2: Loss = 0.3300, Accuracy = 90.47%
# Client 46 Epoch 3: Loss = 0.2612, Accuracy = 90.77%
# Client 46 Epoch 4: Loss = 0.1532, Accuracy = 94.52%
# Client 46 Epoch 5: Loss = 0.1214, Accuracy = 96.32%
# Client 46 Epoch 6: Loss = 0.1019, Accuracy = 96.92%
#
#  Client 47: Local Training
# --------------------------------------------------
# Client 47 Epoch 1: Loss = 0.5368, Accuracy = 82.21%
# Client 47 Epoch 2: Loss = 0.4060, Accuracy = 86.41%
# Client 47 Epoch 3: Loss = 0.2843, Accuracy = 89.41%
# Client 47 Epoch 4: Loss = 0.2058, Accuracy = 92.87%
# Client 47 Epoch 5: Loss = 0.1227, Accuracy = 95.50%
# Client 47 Epoch 6: Loss = 0.0993, Accuracy = 97.15%
#
#  Client 48: Local Training
# --------------------------------------------------
# Client 48 Epoch 1: Loss = 0.4259, Accuracy = 84.68%
# Client 48 Epoch 2: Loss = 0.3340, Accuracy = 87.91%
# Client 48 Epoch 3: Loss = 0.2178, Accuracy = 93.02%
# Client 48 Epoch 4: Loss = 0.1841, Accuracy = 93.39%
# Client 48 Epoch 5: Loss = 0.1430, Accuracy = 95.35%
# Client 48 Epoch 6: Loss = 0.1076, Accuracy = 96.55%
#
#  Client 49: Local Training
# --------------------------------------------------
# Client 49 Epoch 1: Loss = 0.5602, Accuracy = 80.78%
# Client 49 Epoch 2: Loss = 0.3558, Accuracy = 87.99%
# Client 49 Epoch 3: Loss = 0.2623, Accuracy = 90.92%
# Client 49 Epoch 4: Loss = 0.1650, Accuracy = 94.89%
# Client 49 Epoch 5: Loss = 0.1522, Accuracy = 95.87%
# Client 49 Epoch 6: Loss = 0.0975, Accuracy = 97.22%
#
# Federated Learning Round 41:
#   Accuracy: 69.01%, Loss: 0.9562
#
# --- Federated Learning Round 42 ---
#
#  Client 0: Local Training
# --------------------------------------------------
# Client 0 Epoch 1: Loss = 0.2407, Accuracy = 91.63%
# Client 0 Epoch 2: Loss = 0.1293, Accuracy = 96.35%
# Client 0 Epoch 3: Loss = 0.1527, Accuracy = 94.48%
# Client 0 Epoch 4: Loss = 0.1163, Accuracy = 96.45%
# Client 0 Epoch 5: Loss = 0.0581, Accuracy = 97.64%
# Client 0 Epoch 6: Loss = 0.0228, Accuracy = 99.01%
#
#  Client 1: Local Training
# --------------------------------------------------
# Client 1 Epoch 1: Loss = 0.3294, Accuracy = 88.99%
# Client 1 Epoch 2: Loss = 0.2358, Accuracy = 91.32%
# Client 1 Epoch 3: Loss = 0.0965, Accuracy = 95.66%
# Client 1 Epoch 4: Loss = 0.0529, Accuracy = 97.99%
# Client 1 Epoch 5: Loss = 0.0269, Accuracy = 99.28%
# Client 1 Epoch 6: Loss = 0.0183, Accuracy = 99.36%
#
#  Client 2: Local Training
# --------------------------------------------------
# Client 2 Epoch 1: Loss = 0.2586, Accuracy = 91.72%
# Client 2 Epoch 2: Loss = 0.2942, Accuracy = 91.24%
# Client 2 Epoch 3: Loss = 0.1282, Accuracy = 95.50%
# Client 2 Epoch 4: Loss = 0.0542, Accuracy = 98.07%
# Client 2 Epoch 5: Loss = 0.0291, Accuracy = 99.04%
# Client 2 Epoch 6: Loss = 0.0186, Accuracy = 99.52%
#
#  Client 3: Local Training
# --------------------------------------------------
# Client 3 Epoch 1: Loss = 0.3166, Accuracy = 90.62%
# Client 3 Epoch 2: Loss = 0.2165, Accuracy = 92.19%
# Client 3 Epoch 3: Loss = 0.1092, Accuracy = 96.40%
# Client 3 Epoch 4: Loss = 0.0788, Accuracy = 96.85%
# Client 3 Epoch 5: Loss = 0.0476, Accuracy = 98.42%
# Client 3 Epoch 6: Loss = 0.0284, Accuracy = 99.32%
#
#  Client 4: Local Training
# --------------------------------------------------
# Client 4 Epoch 1: Loss = 0.2157, Accuracy = 94.02%
# Client 4 Epoch 2: Loss = 0.0988, Accuracy = 96.82%
# Client 4 Epoch 3: Loss = 0.0463, Accuracy = 98.85%
# Client 4 Epoch 4: Loss = 0.0152, Accuracy = 99.49%
# Client 4 Epoch 5: Loss = 0.0115, Accuracy = 99.68%
# Client 4 Epoch 6: Loss = 0.0079, Accuracy = 99.81%
#
#  Client 5: Local Training
# --------------------------------------------------
# Client 5 Epoch 1: Loss = 0.3478, Accuracy = 88.01%
# Client 5 Epoch 2: Loss = 0.1770, Accuracy = 94.47%
# Client 5 Epoch 3: Loss = 0.0835, Accuracy = 97.07%
# Client 5 Epoch 4: Loss = 0.0891, Accuracy = 96.74%
# Client 5 Epoch 5: Loss = 0.0496, Accuracy = 98.73%
# Client 5 Epoch 6: Loss = 0.0294, Accuracy = 99.00%
#
#  Client 6: Local Training
# --------------------------------------------------
# Client 6 Epoch 1: Loss = 0.2706, Accuracy = 90.38%
# Client 6 Epoch 2: Loss = 0.1096, Accuracy = 96.59%
# Client 6 Epoch 3: Loss = 0.0615, Accuracy = 97.93%
# Client 6 Epoch 4: Loss = 0.0305, Accuracy = 99.27%
# Client 6 Epoch 5: Loss = 0.0279, Accuracy = 99.27%
# Client 6 Epoch 6: Loss = 0.0152, Accuracy = 99.55%
#
#  Client 7: Local Training
# --------------------------------------------------
# Client 7 Epoch 1: Loss = 0.3386, Accuracy = 87.52%
# Client 7 Epoch 2: Loss = 0.2299, Accuracy = 92.09%
# Client 7 Epoch 3: Loss = 0.1128, Accuracy = 96.04%
# Client 7 Epoch 4: Loss = 0.0530, Accuracy = 98.52%
# Client 7 Epoch 5: Loss = 0.0322, Accuracy = 99.07%
# Client 7 Epoch 6: Loss = 0.0229, Accuracy = 99.51%
#
#  Client 8: Local Training
# --------------------------------------------------
# Client 8 Epoch 1: Loss = 0.3449, Accuracy = 88.34%
# Client 8 Epoch 2: Loss = 0.1706, Accuracy = 93.98%
# Client 8 Epoch 3: Loss = 0.0846, Accuracy = 97.80%
# Client 8 Epoch 4: Loss = 0.0591, Accuracy = 97.86%
# Client 8 Epoch 5: Loss = 0.0919, Accuracy = 97.34%
# Client 8 Epoch 6: Loss = 0.0918, Accuracy = 97.09%
#
#  Client 9: Local Training
# --------------------------------------------------
# Client 9 Epoch 1: Loss = 0.2382, Accuracy = 91.85%
# Client 9 Epoch 2: Loss = 0.0920, Accuracy = 96.90%
# Client 9 Epoch 3: Loss = 0.0454, Accuracy = 98.67%
# Client 9 Epoch 4: Loss = 0.0292, Accuracy = 98.93%
# Client 9 Epoch 5: Loss = 0.0291, Accuracy = 98.99%
# Client 9 Epoch 6: Loss = 0.0173, Accuracy = 99.49%
#
#  Client 10: Local Training
# --------------------------------------------------
# Client 10 Epoch 1: Loss = 0.2392, Accuracy = 91.51%
# Client 10 Epoch 2: Loss = 0.0864, Accuracy = 96.88%
# Client 10 Epoch 3: Loss = 0.0458, Accuracy = 98.44%
# Client 10 Epoch 4: Loss = 0.0337, Accuracy = 98.96%
# Client 10 Epoch 5: Loss = 0.0321, Accuracy = 99.08%
# Client 10 Epoch 6: Loss = 0.0221, Accuracy = 99.36%
#
#  Client 11: Local Training
# --------------------------------------------------
# Client 11 Epoch 1: Loss = 0.4092, Accuracy = 84.91%
# Client 11 Epoch 2: Loss = 0.1831, Accuracy = 93.53%
# Client 11 Epoch 3: Loss = 0.0971, Accuracy = 97.20%
# Client 11 Epoch 4: Loss = 0.0569, Accuracy = 98.02%
# Client 11 Epoch 5: Loss = 0.0421, Accuracy = 98.78%
# Client 11 Epoch 6: Loss = 0.0365, Accuracy = 98.95%
#
#  Client 12: Local Training
# --------------------------------------------------
# Client 12 Epoch 1: Loss = 0.2785, Accuracy = 90.09%
# Client 12 Epoch 2: Loss = 0.1118, Accuracy = 96.20%
# Client 12 Epoch 3: Loss = 0.0713, Accuracy = 97.49%
# Client 12 Epoch 4: Loss = 0.0388, Accuracy = 99.10%
# Client 12 Epoch 5: Loss = 0.0286, Accuracy = 99.29%
# Client 12 Epoch 6: Loss = 0.0338, Accuracy = 99.23%
#
#  Client 13: Local Training
# --------------------------------------------------
# Client 13 Epoch 1: Loss = 0.2163, Accuracy = 92.81%
# Client 13 Epoch 2: Loss = 0.0995, Accuracy = 97.19%
# Client 13 Epoch 3: Loss = 0.0506, Accuracy = 98.82%
# Client 13 Epoch 4: Loss = 0.0287, Accuracy = 99.54%
# Client 13 Epoch 5: Loss = 0.0211, Accuracy = 99.41%
# Client 13 Epoch 6: Loss = 0.0179, Accuracy = 99.61%
#
#  Client 14: Local Training
# --------------------------------------------------
# Client 14 Epoch 1: Loss = 0.2701, Accuracy = 89.97%
# Client 14 Epoch 2: Loss = 0.0952, Accuracy = 96.84%
# Client 14 Epoch 3: Loss = 0.0532, Accuracy = 98.21%
# Client 14 Epoch 4: Loss = 0.0363, Accuracy = 98.76%
# Client 14 Epoch 5: Loss = 0.0239, Accuracy = 99.31%
# Client 14 Epoch 6: Loss = 0.0181, Accuracy = 99.52%
#
#  Client 15: Local Training
# --------------------------------------------------
# Client 15 Epoch 1: Loss = 0.3278, Accuracy = 88.24%
# Client 15 Epoch 2: Loss = 0.1586, Accuracy = 94.15%
# Client 15 Epoch 3: Loss = 0.0950, Accuracy = 97.16%
# Client 15 Epoch 4: Loss = 0.0631, Accuracy = 98.41%
# Client 15 Epoch 5: Loss = 0.0507, Accuracy = 98.75%
# Client 15 Epoch 6: Loss = 0.0361, Accuracy = 98.92%
#
#  Client 16: Local Training
# --------------------------------------------------
# Client 16 Epoch 1: Loss = 0.2532, Accuracy = 91.22%
# Client 16 Epoch 2: Loss = 0.1083, Accuracy = 96.45%
# Client 16 Epoch 3: Loss = 0.0692, Accuracy = 98.01%
# Client 16 Epoch 4: Loss = 0.0353, Accuracy = 99.04%
# Client 16 Epoch 5: Loss = 0.0233, Accuracy = 99.46%
# Client 16 Epoch 6: Loss = 0.0183, Accuracy = 99.52%
#
#  Client 17: Local Training
# --------------------------------------------------
# Client 17 Epoch 1: Loss = 0.3597, Accuracy = 87.62%
# Client 17 Epoch 2: Loss = 0.1429, Accuracy = 95.11%
# Client 17 Epoch 3: Loss = 0.0767, Accuracy = 97.88%
# Client 17 Epoch 4: Loss = 0.0572, Accuracy = 98.47%
# Client 17 Epoch 5: Loss = 0.0278, Accuracy = 99.53%
# Client 17 Epoch 6: Loss = 0.0153, Accuracy = 99.65%
#
#  Client 18: Local Training
# --------------------------------------------------
# Client 18 Epoch 1: Loss = 0.2646, Accuracy = 90.88%
# Client 18 Epoch 2: Loss = 0.1350, Accuracy = 95.53%
# Client 18 Epoch 3: Loss = 0.0690, Accuracy = 97.71%
# Client 18 Epoch 4: Loss = 0.0392, Accuracy = 99.09%
# Client 18 Epoch 5: Loss = 0.0241, Accuracy = 99.52%
# Client 18 Epoch 6: Loss = 0.0150, Accuracy = 99.76%
#
#  Client 19: Local Training
# --------------------------------------------------
# Client 19 Epoch 1: Loss = 0.2938, Accuracy = 89.62%
# Client 19 Epoch 2: Loss = 0.1259, Accuracy = 95.27%
# Client 19 Epoch 3: Loss = 0.0673, Accuracy = 97.82%
# Client 19 Epoch 4: Loss = 0.0425, Accuracy = 98.73%
# Client 19 Epoch 5: Loss = 0.0215, Accuracy = 99.58%
# Client 19 Epoch 6: Loss = 0.0183, Accuracy = 99.58%
#
#  Client 20: Local Training
# --------------------------------------------------
# Client 20 Epoch 1: Loss = 0.1883, Accuracy = 93.00%
# Client 20 Epoch 2: Loss = 0.1585, Accuracy = 93.70%
# Client 20 Epoch 3: Loss = 0.0510, Accuracy = 97.97%
# Client 20 Epoch 4: Loss = 0.0297, Accuracy = 99.02%
# Client 20 Epoch 5: Loss = 0.0191, Accuracy = 99.44%
# Client 20 Epoch 6: Loss = 0.0139, Accuracy = 99.72%
#
#  Client 21: Local Training
# --------------------------------------------------
# Client 21 Epoch 1: Loss = 0.2224, Accuracy = 93.11%
# Client 21 Epoch 2: Loss = 0.1009, Accuracy = 96.71%
# Client 21 Epoch 3: Loss = 0.0501, Accuracy = 98.45%
# Client 21 Epoch 4: Loss = 0.0342, Accuracy = 98.78%
# Client 21 Epoch 5: Loss = 0.0297, Accuracy = 99.10%
# Client 21 Epoch 6: Loss = 0.0189, Accuracy = 99.68%
#
#  Client 22: Local Training
# --------------------------------------------------
# Client 22 Epoch 1: Loss = 0.2781, Accuracy = 90.12%
# Client 22 Epoch 2: Loss = 0.1285, Accuracy = 95.98%
# Client 22 Epoch 3: Loss = 0.0775, Accuracy = 97.67%
# Client 22 Epoch 4: Loss = 0.1065, Accuracy = 96.26%
# ...
# Client 9 Epoch 2: Loss = 0.0767, Accuracy = 97.41%
# Client 9 Epoch 3: Loss = 0.0468, Accuracy = 98.42%
# Client 9 Epoch 4: Loss = 0.0227, Accuracy = 99.56%
# Client 9 Epoch 5: Loss = 0.0215, Accuracy = 99.43%
# Client 9 Epoch 6: Loss = 0.0287, Accuracy = 99.30%
#
#  Client 10: Local Training
# --------------------------------------------------
# Client 10 Epoch 1: Loss = 0.2204, Accuracy = 92.44%
# Client 10 Epoch 2: Loss = 0.0850, Accuracy = 97.11%
# Client 10 Epoch 3: Loss = 0.0467, Accuracy = 98.50%
# Client 10 Epoch 4: Loss = 0.0315, Accuracy = 98.90%
# Client 10 Epoch 5: Loss = 0.0206, Accuracy = 99.42%
# Client 10 Epoch 6: Loss = 0.0182, Accuracy = 99.54%
#
#  Client 11: Local Training
# --------------------------------------------------
# Client 11 Epoch 1: Loss = 0.3068, Accuracy = 89.45%
# Client 11 Epoch 2: Loss = 0.1347, Accuracy = 95.45%
# Client 11 Epoch 3: Loss = 0.0811, Accuracy = 97.38%
# Client 11 Epoch 4: Loss = 0.0564, Accuracy = 98.14%
# Client 11 Epoch 5: Loss = 0.0390, Accuracy = 98.83%
# Client 11 Epoch 6: Loss = 0.0228, Accuracy = 99.42%
#
#  Client 12: Local Training
# --------------------------------------------------
# Client 12 Epoch 1: Loss = 0.2466, Accuracy = 91.31%
# Client 12 Epoch 2: Loss = 0.1053, Accuracy = 96.14%
# Client 12 Epoch 3: Loss = 0.0724, Accuracy = 97.62%
# Client 12 Epoch 4: Loss = 0.0322, Accuracy = 99.16%
# Client 12 Epoch 5: Loss = 0.0172, Accuracy = 99.61%
# Client 12 Epoch 6: Loss = 0.0205, Accuracy = 99.42%
#
#  Client 13: Local Training
# --------------------------------------------------
# Client 13 Epoch 1: Loss = 0.1861, Accuracy = 94.24%
# Client 13 Epoch 2: Loss = 0.0688, Accuracy = 97.97%
# Client 13 Epoch 3: Loss = 0.0402, Accuracy = 98.95%
# Client 13 Epoch 4: Loss = 0.0278, Accuracy = 99.35%
# Client 13 Epoch 5: Loss = 0.0252, Accuracy = 99.22%
# Client 13 Epoch 6: Loss = 0.0206, Accuracy = 99.41%
#
#  Client 14: Local Training
# --------------------------------------------------
# Client 14 Epoch 1: Loss = 0.2282, Accuracy = 92.03%
# Client 14 Epoch 2: Loss = 0.1270, Accuracy = 95.60%
# Client 14 Epoch 3: Loss = 0.0799, Accuracy = 97.25%
# Client 14 Epoch 4: Loss = 0.0368, Accuracy = 99.11%
# Client 14 Epoch 5: Loss = 0.0156, Accuracy = 99.79%
# Client 14 Epoch 6: Loss = 0.0159, Accuracy = 99.66%
#
#  Client 15: Local Training
# --------------------------------------------------
# Client 15 Epoch 1: Loss = 0.2589, Accuracy = 91.31%
# Client 15 Epoch 2: Loss = 0.1162, Accuracy = 96.14%
# Client 15 Epoch 3: Loss = 0.0694, Accuracy = 97.84%
# Client 15 Epoch 4: Loss = 0.0512, Accuracy = 98.69%
# Client 15 Epoch 5: Loss = 0.0305, Accuracy = 99.09%
# Client 15 Epoch 6: Loss = 0.0218, Accuracy = 99.43%
#
#  Client 16: Local Training
# --------------------------------------------------
# Client 16 Epoch 1: Loss = 0.2233, Accuracy = 92.72%
# Client 16 Epoch 2: Loss = 0.0742, Accuracy = 97.89%
# Client 16 Epoch 3: Loss = 0.0526, Accuracy = 98.19%
# Client 16 Epoch 4: Loss = 0.0303, Accuracy = 99.34%
# Client 16 Epoch 5: Loss = 0.0217, Accuracy = 99.58%
# Client 16 Epoch 6: Loss = 0.0160, Accuracy = 99.58%
#
#  Client 17: Local Training
# --------------------------------------------------
# Client 17 Epoch 1: Loss = 0.2649, Accuracy = 91.51%
# Client 17 Epoch 2: Loss = 0.1128, Accuracy = 96.64%
# Client 17 Epoch 3: Loss = 0.0541, Accuracy = 98.11%
# Client 17 Epoch 4: Loss = 0.0317, Accuracy = 99.29%
# Client 17 Epoch 5: Loss = 0.0305, Accuracy = 98.88%
# Client 17 Epoch 6: Loss = 0.0243, Accuracy = 99.53%
#
#  Client 18: Local Training
# --------------------------------------------------
# Client 18 Epoch 1: Loss = 0.2243, Accuracy = 92.51%
# Client 18 Epoch 2: Loss = 0.0838, Accuracy = 97.95%
# Client 18 Epoch 3: Loss = 0.0520, Accuracy = 98.37%
# Client 18 Epoch 4: Loss = 0.0239, Accuracy = 99.58%
# Client 18 Epoch 5: Loss = 0.0157, Accuracy = 99.82%
# Client 18 Epoch 6: Loss = 0.0222, Accuracy = 99.40%
#
#  Client 19: Local Training
# --------------------------------------------------
# Client 19 Epoch 1: Loss = 0.2341, Accuracy = 91.99%
# Client 19 Epoch 2: Loss = 0.0915, Accuracy = 96.66%
# Client 19 Epoch 3: Loss = 0.0575, Accuracy = 98.00%
# Client 19 Epoch 4: Loss = 0.0308, Accuracy = 99.03%
# Client 19 Epoch 5: Loss = 0.0190, Accuracy = 99.58%
# Client 19 Epoch 6: Loss = 0.0198, Accuracy = 99.39%
#
#  Client 20: Local Training
# --------------------------------------------------
# Client 20 Epoch 1: Loss = 0.1876, Accuracy = 92.72%
# Client 20 Epoch 2: Loss = 0.0632, Accuracy = 97.62%
# Client 20 Epoch 3: Loss = 0.0343, Accuracy = 99.23%
# Client 20 Epoch 4: Loss = 0.0197, Accuracy = 99.51%
# Client 20 Epoch 5: Loss = 0.0144, Accuracy = 99.58%
# Client 20 Epoch 6: Loss = 0.0084, Accuracy = 99.93%
#
#  Client 21: Local Training
# --------------------------------------------------
# Client 21 Epoch 1: Loss = 0.1619, Accuracy = 94.85%
# Client 21 Epoch 2: Loss = 0.0891, Accuracy = 96.91%
# Client 21 Epoch 3: Loss = 0.0461, Accuracy = 98.45%
# Client 21 Epoch 4: Loss = 0.0328, Accuracy = 99.10%
# Client 21 Epoch 5: Loss = 0.0143, Accuracy = 99.55%
# Client 21 Epoch 6: Loss = 0.0169, Accuracy = 99.42%
#
#  Client 22: Local Training
# --------------------------------------------------
# Client 22 Epoch 1: Loss = 0.2445, Accuracy = 91.88%
# Client 22 Epoch 2: Loss = 0.1729, Accuracy = 94.28%
# Client 22 Epoch 3: Loss = 0.1140, Accuracy = 95.84%
# Client 22 Epoch 4: Loss = 0.0570, Accuracy = 98.31%
# Client 22 Epoch 5: Loss = 0.0274, Accuracy = 99.29%
# Client 22 Epoch 6: Loss = 0.0216, Accuracy = 99.15%
#
#  Client 23: Local Training
# --------------------------------------------------
# Client 23 Epoch 1: Loss = 0.2036, Accuracy = 92.63%
# Client 23 Epoch 2: Loss = 0.1069, Accuracy = 96.70%
# Client 23 Epoch 3: Loss = 0.0477, Accuracy = 98.81%
# Client 23 Epoch 4: Loss = 0.0274, Accuracy = 99.30%
# Client 23 Epoch 5: Loss = 0.0249, Accuracy = 99.37%
# Client 23 Epoch 6: Loss = 0.0239, Accuracy = 99.23%
#
#  Client 24: Local Training
# --------------------------------------------------
# Client 24 Epoch 1: Loss = 0.4004, Accuracy = 84.81%
# Client 24 Epoch 2: Loss = 0.2465, Accuracy = 91.21%
# Client 24 Epoch 3: Loss = 0.1492, Accuracy = 94.50%
# Client 24 Epoch 4: Loss = 0.1079, Accuracy = 96.41%
# Client 24 Epoch 5: Loss = 0.0756, Accuracy = 97.67%
# Client 24 Epoch 6: Loss = 0.0715, Accuracy = 97.61%
#
#  Client 25: Local Training
# --------------------------------------------------
# Client 25 Epoch 1: Loss = 0.3974, Accuracy = 86.65%
# Client 25 Epoch 2: Loss = 0.2625, Accuracy = 90.55%
# Client 25 Epoch 3: Loss = 0.2163, Accuracy = 93.02%
# Client 25 Epoch 4: Loss = 0.1692, Accuracy = 94.75%
# Client 25 Epoch 5: Loss = 0.1398, Accuracy = 95.65%
# Client 25 Epoch 6: Loss = 0.0761, Accuracy = 97.15%
#
#  Client 26: Local Training
# --------------------------------------------------
# Client 26 Epoch 1: Loss = 0.4233, Accuracy = 86.20%
# Client 26 Epoch 2: Loss = 0.3140, Accuracy = 89.12%
# Client 26 Epoch 3: Loss = 0.1875, Accuracy = 94.15%
# Client 26 Epoch 4: Loss = 0.1477, Accuracy = 95.05%
# Client 26 Epoch 5: Loss = 0.1477, Accuracy = 94.82%
# Client 26 Epoch 6: Loss = 0.1484, Accuracy = 95.27%
#
#  Client 27: Local Training
# --------------------------------------------------
# Client 27 Epoch 1: Loss = 0.4106, Accuracy = 85.30%
# Client 27 Epoch 2: Loss = 0.3162, Accuracy = 89.20%
# Client 27 Epoch 3: Loss = 0.1982, Accuracy = 94.07%
# Client 27 Epoch 4: Loss = 0.1592, Accuracy = 94.67%
# Client 27 Epoch 5: Loss = 0.1113, Accuracy = 96.40%
# Client 27 Epoch 6: Loss = 0.1110, Accuracy = 96.32%
#
#  Client 28: Local Training
# --------------------------------------------------
# Client 28 Epoch 1: Loss = 0.3465, Accuracy = 88.67%
# Client 28 Epoch 2: Loss = 0.2606, Accuracy = 91.15%
# Client 28 Epoch 3: Loss = 0.2056, Accuracy = 93.32%
# Client 28 Epoch 4: Loss = 0.1778, Accuracy = 94.07%
# Client 28 Epoch 5: Loss = 0.1648, Accuracy = 94.37%
# Client 28 Epoch 6: Loss = 0.1768, Accuracy = 93.32%
#
#  Client 29: Local Training
# --------------------------------------------------
# Client 29 Epoch 1: Loss = 0.3866, Accuracy = 87.02%
# Client 29 Epoch 2: Loss = 0.2814, Accuracy = 89.95%
# Client 29 Epoch 3: Loss = 0.1879, Accuracy = 93.40%
# Client 29 Epoch 4: Loss = 0.1607, Accuracy = 94.22%
# Client 29 Epoch 5: Loss = 0.1613, Accuracy = 93.92%
# Client 29 Epoch 6: Loss = 0.1457, Accuracy = 94.67%
#
#  Client 30: Local Training
# --------------------------------------------------
# Client 30 Epoch 1: Loss = 0.3976, Accuracy = 85.22%
# Client 30 Epoch 2: Loss = 0.2634, Accuracy = 90.55%
# Client 30 Epoch 3: Loss = 0.2342, Accuracy = 92.72%
# Client 30 Epoch 4: Loss = 0.2157, Accuracy = 92.42%
# Client 30 Epoch 5: Loss = 0.1773, Accuracy = 93.70%
# Client 30 Epoch 6: Loss = 0.1280, Accuracy = 95.50%
#
#  Client 31: Local Training
# --------------------------------------------------
# Client 31 Epoch 1: Loss = 0.3711, Accuracy = 86.95%
# Client 31 Epoch 2: Loss = 0.2513, Accuracy = 91.67%
# Client 31 Epoch 3: Loss = 0.1962, Accuracy = 93.17%
# Client 31 Epoch 4: Loss = 0.1517, Accuracy = 95.12%
# Client 31 Epoch 5: Loss = 0.1100, Accuracy = 96.32%
# Client 31 Epoch 6: Loss = 0.1233, Accuracy = 96.10%
#
#  Client 32: Local Training
# --------------------------------------------------
# Client 32 Epoch 1: Loss = 0.3834, Accuracy = 85.75%
# Client 32 Epoch 2: Loss = 0.2879, Accuracy = 89.05%
# Client 32 Epoch 3: Loss = 0.2502, Accuracy = 90.77%
# Client 32 Epoch 4: Loss = 0.2074, Accuracy = 92.87%
# Client 32 Epoch 5: Loss = 0.1682, Accuracy = 94.30%
# Client 32 Epoch 6: Loss = 0.1067, Accuracy = 96.55%
#
#  Client 33: Local Training
# --------------------------------------------------
# Client 33 Epoch 1: Loss = 0.3658, Accuracy = 88.15%
# Client 33 Epoch 2: Loss = 0.3189, Accuracy = 89.50%
# Client 33 Epoch 3: Loss = 0.2225, Accuracy = 92.27%
# Client 33 Epoch 4: Loss = 0.1732, Accuracy = 94.30%
# Client 33 Epoch 5: Loss = 0.1454, Accuracy = 95.12%
# Client 33 Epoch 6: Loss = 0.1097, Accuracy = 96.25%
#
#  Client 34: Local Training
# --------------------------------------------------
# Client 34 Epoch 1: Loss = 0.3232, Accuracy = 88.90%
# Client 34 Epoch 2: Loss = 0.2834, Accuracy = 89.50%
# Client 34 Epoch 3: Loss = 0.2290, Accuracy = 92.50%
# Client 34 Epoch 4: Loss = 0.1392, Accuracy = 95.12%
# Client 34 Epoch 5: Loss = 0.1396, Accuracy = 95.72%
# Client 34 Epoch 6: Loss = 0.1287, Accuracy = 96.02%
#
#  Client 35: Local Training
# --------------------------------------------------
# Client 35 Epoch 1: Loss = 0.3840, Accuracy = 87.55%
# Client 35 Epoch 2: Loss = 0.2640, Accuracy = 91.37%
# Client 35 Epoch 3: Loss = 0.2086, Accuracy = 93.02%
# Client 35 Epoch 4: Loss = 0.1500, Accuracy = 94.82%
# Client 35 Epoch 5: Loss = 0.1196, Accuracy = 96.40%
# Client 35 Epoch 6: Loss = 0.1033, Accuracy = 96.55%
#
#  Client 36: Local Training
# --------------------------------------------------
# Client 36 Epoch 1: Loss = 0.3674, Accuracy = 87.77%
# Client 36 Epoch 2: Loss = 0.2489, Accuracy = 91.07%
# Client 36 Epoch 3: Loss = 0.2598, Accuracy = 92.27%
# Client 36 Epoch 4: Loss = 0.1527, Accuracy = 94.45%
# Client 36 Epoch 5: Loss = 0.1388, Accuracy = 95.72%
# Client 36 Epoch 6: Loss = 0.1574, Accuracy = 94.90%
#
#  Client 37: Local Training
# --------------------------------------------------
# Client 37 Epoch 1: Loss = 0.4333, Accuracy = 85.60%
# Client 37 Epoch 2: Loss = 0.2331, Accuracy = 91.67%
# Client 37 Epoch 3: Loss = 0.1920, Accuracy = 94.15%
# Client 37 Epoch 4: Loss = 0.1490, Accuracy = 95.12%
# Client 37 Epoch 5: Loss = 0.1505, Accuracy = 95.50%
# Client 37 Epoch 6: Loss = 0.1262, Accuracy = 96.02%
#
#  Client 38: Local Training
# --------------------------------------------------
# Client 38 Epoch 1: Loss = 0.3502, Accuracy = 87.25%
# Client 38 Epoch 2: Loss = 0.2932, Accuracy = 90.02%
# Client 38 Epoch 3: Loss = 0.2387, Accuracy = 92.27%
# Client 38 Epoch 4: Loss = 0.2333, Accuracy = 92.72%
# Client 38 Epoch 5: Loss = 0.1647, Accuracy = 94.82%
# Client 38 Epoch 6: Loss = 0.1169, Accuracy = 95.65%
#
#  Client 39: Local Training
# --------------------------------------------------
# Client 39 Epoch 1: Loss = 0.3353, Accuracy = 88.07%
# Client 39 Epoch 2: Loss = 0.2466, Accuracy = 91.52%
# Client 39 Epoch 3: Loss = 0.2087, Accuracy = 92.95%
# Client 39 Epoch 4: Loss = 0.2463, Accuracy = 92.05%
# Client 39 Epoch 5: Loss = 0.1564, Accuracy = 94.60%
# Client 39 Epoch 6: Loss = 0.1158, Accuracy = 96.32%
#
#  Client 40: Local Training
# --------------------------------------------------
# Client 40 Epoch 1: Loss = 0.3505, Accuracy = 88.15%
# Client 40 Epoch 2: Loss = 0.2202, Accuracy = 92.57%
# Client 40 Epoch 3: Loss = 0.2851, Accuracy = 90.10%
# Client 40 Epoch 4: Loss = 0.2277, Accuracy = 91.67%
# Client 40 Epoch 5: Loss = 0.2118, Accuracy = 93.10%
# Client 40 Epoch 6: Loss = 0.1403, Accuracy = 95.65%
#
#  Client 41: Local Training
# --------------------------------------------------
# Client 41 Epoch 1: Loss = 0.3606, Accuracy = 87.25%
# Client 41 Epoch 2: Loss = 0.2825, Accuracy = 90.32%
# Client 41 Epoch 3: Loss = 0.2546, Accuracy = 91.07%
# Client 41 Epoch 4: Loss = 0.2183, Accuracy = 92.27%
# Client 41 Epoch 5: Loss = 0.1266, Accuracy = 95.87%
# Client 41 Epoch 6: Loss = 0.1068, Accuracy = 96.47%
#
#  Client 42: Local Training
# --------------------------------------------------
# Client 42 Epoch 1: Loss = 0.3713, Accuracy = 87.25%
# Client 42 Epoch 2: Loss = 0.2723, Accuracy = 90.92%
# Client 42 Epoch 3: Loss = 0.1731, Accuracy = 93.85%
# Client 42 Epoch 4: Loss = 0.1873, Accuracy = 93.92%
# Client 42 Epoch 5: Loss = 0.1842, Accuracy = 94.07%
# Client 42 Epoch 6: Loss = 0.1164, Accuracy = 95.87%
#
#  Client 43: Local Training
# --------------------------------------------------
# Client 43 Epoch 1: Loss = 0.3691, Accuracy = 86.87%
# Client 43 Epoch 2: Loss = 0.2841, Accuracy = 89.87%
# Client 43 Epoch 3: Loss = 0.2086, Accuracy = 92.65%
# Client 43 Epoch 4: Loss = 0.1490, Accuracy = 94.45%
# Client 43 Epoch 5: Loss = 0.1103, Accuracy = 96.32%
# Client 43 Epoch 6: Loss = 0.0776, Accuracy = 97.30%
#
#  Client 44: Local Training
# --------------------------------------------------
# Client 44 Epoch 1: Loss = 0.3966, Accuracy = 86.57%
# Client 44 Epoch 2: Loss = 0.2557, Accuracy = 91.07%
# Client 44 Epoch 3: Loss = 0.1882, Accuracy = 93.10%
# Client 44 Epoch 4: Loss = 0.1441, Accuracy = 95.80%
# Client 44 Epoch 5: Loss = 0.1281, Accuracy = 95.80%
# Client 44 Epoch 6: Loss = 0.1055, Accuracy = 96.77%
#
#  Client 45: Local Training
# --------------------------------------------------
# Client 45 Epoch 1: Loss = 0.3208, Accuracy = 89.11%
# Client 45 Epoch 2: Loss = 0.2213, Accuracy = 92.49%
# Client 45 Epoch 3: Loss = 0.1514, Accuracy = 94.52%
# Client 45 Epoch 4: Loss = 0.1616, Accuracy = 94.74%
# Client 45 Epoch 5: Loss = 0.1600, Accuracy = 95.27%
# Client 45 Epoch 6: Loss = 0.1380, Accuracy = 95.50%
#
#  Client 46: Local Training
# --------------------------------------------------
# Client 46 Epoch 1: Loss = 0.3599, Accuracy = 88.06%
# Client 46 Epoch 2: Loss = 0.3263, Accuracy = 88.44%
# Client 46 Epoch 3: Loss = 0.1923, Accuracy = 93.77%
# Client 46 Epoch 4: Loss = 0.1439, Accuracy = 94.89%
# Client 46 Epoch 5: Loss = 0.1274, Accuracy = 95.27%
# Client 46 Epoch 6: Loss = 0.0772, Accuracy = 97.45%
#
#  Client 47: Local Training
# --------------------------------------------------
# Client 47 Epoch 1: Loss = 0.4129, Accuracy = 85.66%
# Client 47 Epoch 2: Loss = 0.2936, Accuracy = 89.34%
# Client 47 Epoch 3: Loss = 0.2465, Accuracy = 92.72%
# Client 47 Epoch 4: Loss = 0.1832, Accuracy = 93.32%
# Client 47 Epoch 5: Loss = 0.1402, Accuracy = 94.67%
# Client 47 Epoch 6: Loss = 0.1054, Accuracy = 96.47%
#
#  Client 48: Local Training
# --------------------------------------------------
# Client 48 Epoch 1: Loss = 0.3143, Accuracy = 89.49%
# Client 48 Epoch 2: Loss = 0.2043, Accuracy = 93.09%
# Client 48 Epoch 3: Loss = 0.1908, Accuracy = 93.17%
# Client 48 Epoch 4: Loss = 0.1884, Accuracy = 93.77%
# Client 48 Epoch 5: Loss = 0.1878, Accuracy = 93.99%
# Client 48 Epoch 6: Loss = 0.1210, Accuracy = 95.57%
#
#  Client 49: Local Training
# --------------------------------------------------
# Client 49 Epoch 1: Loss = 0.3496, Accuracy = 88.06%
# Client 49 Epoch 2: Loss = 0.2465, Accuracy = 91.52%
# Client 49 Epoch 3: Loss = 0.1641, Accuracy = 94.07%
# Client 49 Epoch 4: Loss = 0.1518, Accuracy = 95.87%
# Client 49 Epoch 5: Loss = 0.1087, Accuracy = 96.47%
# Client 49 Epoch 6: Loss = 0.1458, Accuracy = 95.50%
#
# Federated Learning Round 50:
#   Accuracy: 69.33%, Loss: 0.9632

# %% [markdown]
# ### Plot Accuracy Curve

# %%
plt.figure(figsize=(20, 8))
plt.plot(range(1, FL_ROUNDS + 1), global_accuracy_list, marker='o')
plt.xlabel('Round')
plt.ylabel('Test Accuracy (%)')
plt.title('Federated Learning Accuracy for FedAvg on CIFAR-10')
plt.grid(True)
plt.xticks(range(1, 51))  # Set x-axis from 1 to 20
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(range(1, FL_ROUNDS + 1), global_loss_list, marker='o')
plt.xlabel('Round')
plt.ylabel('Loss')
plt.title('Federated Learning Loss with FedAvg on CIFAR-10')
plt.grid(True)
plt.xticks(range(1, 51))  # Set x-axis from 1 to 20
plt.show()

# %%
import pickle

with open('/content/drive/MyDrive/FYP/Implementations/history/fedavg/accuracy_history.pkl', 'wb') as f:
    pickle.dump(global_accuracy_list, f)

with open('/content/drive/MyDrive/FYP/Implementations/history/fedavg/loss_history.pkl', 'wb') as f:
  pickle.dump(global_loss_list, f)
